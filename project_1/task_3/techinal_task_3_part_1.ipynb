# %%
import pandas as pd
import numpy as np

# %%
company = pd.read_csv('Company Descriptions.csv')
company
# Out:
#                 company_name  \
# 0                 Codementor
# 1                    AgShift
# 2                     Shipsi
# 3                   OpenNews
# 4           Biobot Analytics
# ...                      ...
# 19960  Powermat Technologies
# 19961               Properly
# 19962                Bid Ops
# 19963                 Tavolo
# 19964               StackMob
#
#                                company_short_description  \
# 0      Codementor is an online marketplace connecting...
# 1      AgShift is designing world's most advanced aut...
# 2      Shipsi empowers any retailer with the ability ...
# 3      OpenNews helps a global network of developers,...
# 4      Biobot Analytics analyzes city sewage to estim...
# ...                                                  ...
# 19960  Powermat Technologies develops wireless energy...
# 19961  The Ultimate Turnover Tool for Vacation Rental...
# 19962  Bid Ops accelerates business partnerships betw...
# 19963  Tavolo is an online retailer and destination f...
# 19964  StackMob is a mobile platform helping develope...
#
#                                      company_description
# 0      Codementor provides live 1:1 help for software...
# 1      AgShift solution blends Deep Learning with Com...
# 2      Shipsi empowers any retailer with the ability ...
# 3      We're helping a global network of developers, ...
# 4      Biobot Analytics analyzes sewage to estimate o...
# ...                                                  ...
# 19960  Powermat Technologies is a developer of wirele...
# 19961  Properly is a visual checklist tool that lets ...
# 19962                                                NaN
# 19963  Tavolo offers an online store that enables its...
# 19964  StackMob’s mobile platform helps developers cr...
#
# [19965 rows x 3 columns]

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19965 entries, 0 to 19964
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   company_name               19965 non-null  object
#  1   company_short_description  19965 non-null  object
#  2   company_description        19237 non-null  object
# dtypes: object(3)
# memory usage: 468.1+ KB

# %%
# importing missing value in company_description with short decription
company.company_description = company.company_description.fillna(company.company_short_description)

# %%
company = company.drop(['company_short_description'],axis=1)

# %%
company.head()
# Out:
#        company_name                                company_description
# 0        Codementor  Codementor provides live 1:1 help for software...
# 1           AgShift  AgShift solution blends Deep Learning with Com...
# 2            Shipsi  Shipsi empowers any retailer with the ability ...
# 3          OpenNews  We're helping a global network of developers, ...
# 4  Biobot Analytics  Biobot Analytics analyzes sewage to estimate o...

# %% [markdown]
# # Text preprocessing

# %%
company.company_description = company.company_description.apply(lambda x: x.lower())

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(text):
    text_nopunctuation="".join([c for c in text if c not in string.punctuation])
    return text_nopunctuation

# %%
company.company_description = company.company_description.apply(remove_punctuation)

# %%
def remove_digit(text):
    result = ''.join([i for i in text if not i.isdigit()])
    return result

# %%
company.company_description = company.company_description.apply(remove_digit)

# %%
#defining function for tokenization
import re
def tokenization(text):
    tokens = re.split('W+',text)
    return tokens
#applying function to the column
company.company_description = company.company_description.apply(lambda x: tokenization(x))

# %%
#importing nlp library
import nltk
#Stop words present in the library
stopwords = nltk.corpus.stopwords.words('english')
#defining the function to remove stopwords from tokenized text
def remove_stopwords(text):
    output= [i for i in text if i not in stopwords]
    return output
#applying the function
company.company_description = company.company_description.apply(lambda x:remove_stopwords(x))

# %%
from nltk.stem import WordNetLemmatizer
#defining the object for Lemmatization
wordnet_lemmatizer = WordNetLemmatizer()
#defining the function for lemmatization
def lemmatizer(text):
    lemm_text = [wordnet_lemmatizer.lemmatize(word) for word in text]
    return lemm_text
company.company_description = company.company_description.apply(lambda x:lemmatizer(x))

# %%
company.company_description = company.company_description.apply(lambda x: ' '.join(x))

# %%
company
# Out:
#                 company_name  \
# 0                 Codementor
# 1                    AgShift
# 2                     Shipsi
# 3                   OpenNews
# 4           Biobot Analytics
# ...                      ...
# 19960  Powermat Technologies
# 19961               Properly
# 19962                Bid Ops
# 19963                 Tavolo
# 19964               StackMob
#
#                                      company_description
# 0      codementor provides live  help for software de...
# 1      agshift solution blends deep learning with com...
# 2      shipsi empowers any retailer with the ability ...
# 3      were helping a global network of developers jo...
# 4      biobot analytics analyzes sewage to estimate o...
# ...                                                  ...
# 19960  powermat technologies is a developer of wirele...
# 19961  properly is a visual checklist tool that lets ...
# 19962  bid ops accelerates business partnerships betw...
# 19963  tavolo offers an online store that enables its...
# 19964  stackmob’s mobile platform helps developers cr...
#
# [19965 rows x 2 columns]

# %%
# Import library
from keybert import KeyBERT

kw_model = KeyBERT()

# %%
company.company_description[0]
# Out:
# 'codementor provides live  help for software development  we’re making it easy for developers to connect with experts via screen sharing video and chat  there are two ways to get help ondemand live  expert help and longterm dedicated mentorship \n\nbuild projects faster with ondemand help for topics including ruby python php javascript csshtml ios swift and more codementor helps you overcome key challenges with timely advice and speeds up your development process'

# %%
keywords=kw_model.extract_keywords(company.company_description,top_n=10)

# %%
keywords
# Out:
# [[('codementor', 0.5403),
#   ('developers', 0.4031),
#   ('mentorship', 0.3955),
#   ('software', 0.3319),
#   ('swift', 0.3225),
#   ('development', 0.3224),
#   ('ios', 0.3212),
#   ('projects', 0.3024),
#   ('chat', 0.269),
#   ('build', 0.2616)],
#  [('agshift', 0.3913),
#   ('software', 0.3842),
#   ('learning', 0.3584),
#   ('vision', 0.3491),
#   ('images', 0.3458),
#   ('deep', 0.343),
#   ('inspections', 0.3306),
#   ('defects', 0.309),
#   ('image', 0.3085),
#   ('models', 0.2992)],
#  [('shipsi', 0.6162),
#   ('logistics', 0.3932),
#   ('shipping', 0.3858),
#   ('retailer', 0.3648),
#   ('delivery', 0.3358),
#   ('headquartered', 0.2963),
#   ('checkout', 0.2593),
#   ('founded', 0.2499),
#   ('order', 0.2172),
#   ('california', 0.2101)],
#  [('developers', 0.5045),
#   ('journalism', 0.4972),
#   ('journalists', 0.4827),
#   ('hackers', 0.4502),
#   ('collaborate', 0.4312),
#   ('community', 0.402),
#   ('tools', 0.3819),
#   ('web', 0.3527),
#   ('peers', 0.3439),
#   ('makers', 0.3203)],
#  [('biobot', 0.4356),
#   ('wastewater', 0.4233),
#   ('opioids', 0.4156),
#   ('sewage', 0.4132),
#   ('analytics', 0.3882),
#   ('opioid', 0.3805),
#   ('sewers', 0.3788),
#   ('analyzes', 0.3201),
#   ('analyze', 0.303),
#   ('data', 0.2987)],
#  [('netclerk', 0.6241),
#   ('permitcentral', 0.485),
#   ('permits', 0.4113),
#   ('provider', 0.3508),
#   ('contractors', 0.3225),
#   ('builders', 0.2893),
#   ('forms', 0.2791),
#   ('provides', 0.258),
#   ('companys', 0.2559),
#   ('asp', 0.2557)],
#  [('satellier', 0.6222),
#   ('satelliers', 0.5933),
#   ('architectural', 0.3896),
#   ('visual', 0.3454),
#   ('design', 0.3249),
#   ('digital', 0.3026),
#   ('buildings', 0.2974),
#   ('virtual', 0.2968),
#   ('engineering', 0.2968),
#   ('vdc', 0.2806)],
#  [('medcases', 0.6718),
#   ('adhd', 0.4568),
#   ('pharmaceutical', 0.442),
#   ('medical', 0.402),
#   ('physicians', 0.3913),
#   ('hyperactivity', 0.3811),
#   ('diagnosis', 0.2971),
#   ('disorder', 0.2768),
#   ('lifesystems', 0.2695),
#   ('treatment', 0.2595)],
#  [('speeddatecom', 0.677),
#   ('webcam', 0.4971),
#   ('realtime', 0.367),
#   ('matchcom', 0.3583),
#   ('chat', 0.3395),
#   ('dating', 0.3378),
#   ('dates', 0.3337),
#   ('speed', 0.326),
#   ('messaging', 0.3233),
#   ('eharmony', 0.2859)],
#  [('biotechnologies', 0.5156),
#   ('biotechnology', 0.4431),
#   ('raven', 0.3944),
#   ('antibody', 0.3328),
#   ('cancer', 0.3102),
#   ('rav', 0.3018),
#   ('therapeutics', 0.2908),
#   ('company', 0.2859),
#   ('macrogenics', 0.2835),
#   ('founded', 0.2779)],
#  [('clothing', 0.4757),
#   ('essentials', 0.402),
#   ('prices', 0.3516),
#   ('kids', 0.3414),
#   ('box', 0.3034),
#   ('quality', 0.2444),
#   ('building', 0.2196),
#   ('everyday', 0.167),
#   ('low', 0.1467),
#   ('high', 0.0508)],
#  [('xtremespectrum', 0.6685),
#   ('ultrawideband', 0.5212),
#   ('radio', 0.3639),
#   ('wireless', 0.3322),
#   ('uwb', 0.3266),
#   ('displays', 0.2509),
#   ('digital', 0.2368),
#   ('recorders', 0.2213),
#   ('technology', 0.2212),
#   ('cameras', 0.2005)],
#  [('windmil', 0.5868),
#   ('oncology', 0.3846),
#   ('therapies', 0.3302),
#   ('therapeutics', 0.3174),
#   ('cell', 0.2375),
#   ('indications', 0.1581),
#   ('developing', 0.1083)],
#  [('alacra', 0.6041),
#   ('alacras', 0.587),
#   ('firms', 0.3512),
#   ('corporation', 0.3385),
#   ('corporations', 0.3268),
#   ('business', 0.3219),
#   ('company', 0.3219),
#   ('regulatory', 0.3076),
#   ('publishers', 0.3038),
#   ('suppliers', 0.2763)],
#  [('petdesk', 0.6753),
#   ('pet', 0.4528),
#   ('pets', 0.4352),
#   ('vets', 0.3467),
#   ('services', 0.3453),
#   ('software', 0.3376),
#   ('app', 0.3255),
#   ('clients', 0.3203),
#   ('saas', 0.3169),
#   ('providers', 0.3055)],
#  [('coaching', 0.4588),
#   ('wellness', 0.4503),
#   ('employees', 0.3577),
#   ('ally', 0.3563),
#   ('financial', 0.3285),
#   ('education', 0.3261),
#   ('stress', 0.2881),
#   ('company', 0.2845),
#   ('helping', 0.2834),
#   ('independent', 0.2585)],
#  [('comstellar', 0.512),
#   ('communications', 0.4936),
#   ('technologies', 0.4839),
#   ('technology', 0.4441),
#   ('infrastructure', 0.4421),
#   ('innovative', 0.3543),
#   ('company', 0.252),
#   ('opportunities', 0.2473),
#   ('worldwide', 0.2255),
#   ('building', 0.2166)],
#  [('wines', 0.4511),
#   ('wine', 0.4191),
#   ('lot', 0.3983),
#   ('auction', 0.3672),
#   ('membership', 0.302),
#   ('coveted', 0.2823),
#   ('website', 0.2822),
#   ('club', 0.2744),
#   ('products', 0.2651),
#   ('bid', 0.2579)],
#  [('roam', 0.7751),
#   ('adventurer', 0.5882),
#   ('global', 0.4027),
#   ('community', 0.4016),
#   ('generation', 0.3117)],
#  [('homebase', 0.5424),
#   ('scheduling', 0.432),
#   ('hourly', 0.4237),
#   ('timesheets', 0.3021),
#   ('employees', 0.2917),
#   ('tools', 0.2796),
#   ('free', 0.2775),
#   ('administrative', 0.2636),
#   ('pricing', 0.2384),
#   ('automating', 0.2293)],
#  [('miro', 0.4921),
#   ('collaborative', 0.4787),
#   ('collaboration', 0.4683),
#   ('collaborate', 0.4317),
#   ('clients', 0.3873),
#   ('platform', 0.3508),
#   ('slack', 0.3432),
#   ('whiteboards', 0.3429),
#   ('applications', 0.3405),
#   ('app', 0.3313)],
#  [('tenebril', 0.6947),
#   ('spyware', 0.4264),
#   ('security', 0.2599),
#   ('software', 0.2591),
#   ('ecommerce', 0.2572),
#   ('innovative', 0.255),
#   ('distributed', 0.2474),
#   ('privacy', 0.24),
#   ('product', 0.2354),
#   ('zeroday', 0.2339)],
#  [('novo', 0.6845),
#   ('novobranded', 0.4991),
#   ('banking', 0.4371),
#   ('banks', 0.432),
#   ('fdicinsured', 0.2669),
#   ('platform', 0.2289),
#   ('depository', 0.2274),
#   ('profitable', 0.2023),
#   ('business', 0.1719),
#   ('products', 0.1537)],
#  [('shenandoah', 0.5482),
#   ('chicken', 0.4056),
#   ('organic', 0.3808),
#   ('valley', 0.3698),
#   ('virginia', 0.3681),
#   ('farms', 0.3636),
#   ('harrisonburg', 0.3374),
#   ('located', 0.2989),
#   ('company', 0.2154),
#   ('pesticides', 0.2126)],
#  [('neurovance', 0.5859),
#   ('venture', 0.3778),
#   ('prozac', 0.3405),
#   ('neuroscience', 0.3392),
#   ('investors', 0.3349),
#   ('zyprexa', 0.3218),
#   ('novartis', 0.303),
#   ('medications', 0.2956),
#   ('partners', 0.2922),
#   ('cymbalta', 0.2787)],
#  [('technology', 0.5036),
#   ('thebrain', 0.4235),
#   ('projects', 0.3958),
#   ('brains', 0.3909),
#   ('organize', 0.2749),
#   ('thinking', 0.2491),
#   ('information', 0.2451),
#   ('helps', 0.2075),
#   ('extend', 0.1701),
#   ('life', 0.1675)],
#  [('soundhawk', 0.5604),
#   ('hearing', 0.5108),
#   ('listening', 0.4902),
#   ('listen', 0.4033),
#   ('hear', 0.3662),
#   ('apple', 0.3153),
#   ('cisco', 0.3017),
#   ('palm', 0.2577),
#   ('world', 0.2324),
#   ('worlds', 0.229)],
#  [('customers', 0.4246),
#   ('depot', 0.4109),
#   ('merchants', 0.375),
#   ('marketing', 0.3511),
#   ('customer', 0.3492),
#   ('crowdsavings', 0.3117),
#   ('ncrowd', 0.307),
#   ('advertising', 0.3047),
#   ('acquire', 0.3003),
#   ('acquisition', 0.298)],
#  [('enclarity', 0.481),
#   ('insurance', 0.3652),
#   ('provider', 0.3495),
#   ('healthcare', 0.3458),
#   ('database', 0.3164),
#   ('information', 0.3004),
#   ('medical', 0.2803),
#   ('wwwenclaritycom', 0.2747),
#   ('manufacturers', 0.2508),
#   ('compliance', 0.2493)],
#  [('synapsify', 0.6872),
#   ('analytics', 0.3598),
#   ('insight', 0.3107),
#   ('text', 0.302),
#   ('tool', 0.2882),
#   ('core', 0.2781),
#   ('data', 0.2673),
#   ('readers', 0.2574),
#   ('content', 0.2424),
#   ('researchers', 0.2337)],
#  [('xshares', 0.5838),
#   ('exchangetraded', 0.3644),
#   ('funds', 0.2957),
#   ('company', 0.2752),
#   ('group', 0.2617),
#   ('distributes', 0.2538),
#   ('financial', 0.253),
#   ('united', 0.2188),
#   ('york', 0.1998),
#   ('based', 0.1655)],
#  [('newisys', 0.4354),
#   ('service', 0.2811),
#   ('performance', 0.2717),
#   ('data', 0.2561),
#   ('efficiency', 0.2519),
#   ('cost', 0.219),
#   ('new', 0.2167),
#   ('center', 0.1977),
#   ('economy', 0.1928),
#   ('environments', 0.1847)],
#  [('epitranscriptomics', 0.7484),
#   ('therapeutics', 0.3661),
#   ('drug', 0.3437),
#   ('gotham', 0.226),
#   ('novel', 0.2012),
#   ('targeting', 0.1579),
#   ('class', 0.0904),
#   ('discovering', 0.0862),
#   ('machinery', 0.0437)],
#  [('bioplastic', 0.5763),
#   ('biocomposites', 0.4776),
#   ('biodegradable', 0.4689),
#   ('plastics', 0.4607),
#   ('sustainability', 0.4526),
#   ('green', 0.4478),
#   ('sustainable', 0.4265),
#   ('recycled', 0.4072),
#   ('resins', 0.3725),
#   ('plastic', 0.346)],
#  [('flying', 0.4037),
#   ('brothers', 0.3461),
#   ('guitarist', 0.2664),
#   ('band', 0.2528),
#   ('rogers', 0.1817),
#   ('frontier', 0.1737),
#   ('electronic', 0.1493),
#   ('venture', 0.1458),
#   ('computers', 0.1443),
#   ('lounges', 0.1443)],
#  [('knotice', 0.6292),
#   ('knoticeâ', 0.5861),
#   ('concentriâ', 0.373),
#   ('mobile', 0.328),
#   ('web', 0.315),
#   ('digital', 0.3114),
#   ('marketing', 0.3051),
#   ('software', 0.3033),
#   ('services', 0.2797),
#   ('email', 0.2748)],
#  [('mobileserve', 0.8147),
#   ('mobile', 0.5453),
#   ('application', 0.3337),
#   ('applications', 0.3223),
#   ('service', 0.3201),
#   ('volunteerism', 0.3172),
#   ('developer', 0.2612),
#   ('social', 0.2516),
#   ('tracking', 0.2135),
#   ('community', 0.2089)],
#  [('heartflow', 0.7133),
#   ('cardiovascular', 0.4713),
#   ('coronary', 0.3257),
#   ('artery', 0.2967),
#   ('physiology', 0.2607),
#   ('medical', 0.2218),
#   ('simulation', 0.2106),
#   ('physician', 0.1813),
#   ('technology', 0.1534),
#   ('redwood', 0.1426)],
#  [('bioengineered', 0.5823),
#   ('tissueengineered', 0.5438),
#   ('biohealing', 0.4989),
#   ('fdaapproved', 0.4111),
#   ('advanced', 0.4016),
#   ('clinical', 0.3807),
#   ('regenerative', 0.3794),
#   ('commercialization', 0.37),
#   ('industry', 0.3692),
#   ('medicine', 0.3569)],
#  [('muffins', 0.595),
#   ('foods', 0.3898),
#   ('dairy', 0.3764),
#   ('gmos', 0.3653),
#   ('gluten', 0.361),
#   ('healthiest', 0.3508),
#   ('peanuts', 0.3493),
#   ('grains', 0.3466),
#   ('allergies', 0.3436),
#   ('preservatives', 0.3316)],
#  [('iwon', 0.6301),
#   ('search', 0.4188),
#   ('portal', 0.414),
#   ('content', 0.31),
#   ('functionality', 0.2991),
#   ('destination', 0.2945),
#   ('cbsbacked', 0.2898),
#   ('combines', 0.1196)],
#  [('automation', 0.6378),
#   ('robotics', 0.5298),
#   ('otto', 0.4641),
#   ('models', 0.3939),
#   ('business', 0.3115),
#   ('crafting', 0.2366),
#   ('building', 0.1752),
#   ('uniquely', 0.1652),
#   ('new', 0.148),
#   ('blocks', 0.139)],
#  [('gps', 0.5071),
#   ('fleetasapsm', 0.4753),
#   ('fleetasap', 0.4664),
#   ('locationbased', 0.4271),
#   ('provider', 0.4107),
#   ('road', 0.4018),
#   ('fleet', 0.3969),
#   ('internetbased', 0.3856),
#   ('mobile', 0.3683),
#   ('telematics', 0.3681)],
#  [('chipx', 0.6819),
#   ('asics', 0.5184),
#   ('asic', 0.4724),
#   ('pci', 0.3993),
#   ('integrated', 0.2617),
#   ('silicon', 0.2403),
#   ('express', 0.2338),
#   ('mixedsignal', 0.2263),
#   ('ca', 0.2192),
#   ('corporation', 0.2186)],
#  [('saveup', 0.6133),
#   ('savings', 0.5189),
#   ('saving', 0.4855),
#   ('rewards', 0.4344),
#   ('saved', 0.3769),
#   ('debt', 0.3559),
#   ('debts', 0.3337),
#   ('financial', 0.328),
#   ('loans', 0.312),
#   ('prizes', 0.3045)],
#  [('peak', 0.4552),
#   ('surgery', 0.4464),
#   ('surgical', 0.4407),
#   ('electrosurgery', 0.4299),
#   ('orthopedic', 0.3304),
#   ('spinal', 0.2919),
#   ('medical', 0.2722),
#   ('scalpel', 0.2713),
#   ('procedures', 0.2558),
#   ('arthroscopic', 0.2356)],
#  [('quinnova', 0.5353),
#   ('pharmaceutical', 0.5296),
#   ('pharmaceuticals', 0.5011),
#   ('prescription', 0.4228),
#   ('treatment', 0.3439),
#   ('drug', 0.3261),
#   ('nail', 0.31),
#   ('nails', 0.3004),
#   ('dermatitis', 0.2808),
#   ('tersi', 0.2697)],
#  [('extricity', 0.5339),
#   ('inovis', 0.4588),
#   ('businesstobusiness', 0.4051),
#   ('external', 0.3709),
#   ('acquired', 0.3704),
#   ('companies', 0.3176),
#   ('company', 0.3162),
#   ('partners', 0.3069),
#   ('business', 0.3042),
#   ('internal', 0.287)],
#  [('xova', 0.4319),
#   ('venture', 0.4223),
#   ('cloud', 0.3645),
#   ('mobile', 0.3629),
#   ('enterprise', 0.3108),
#   ('infrastructure', 0.3103),
#   ('labs', 0.2898),
#   ('technology', 0.2618),
#   ('software', 0.235),
#   ('mission', 0.222)],
#  [('kubernetes', 0.6015),
#   ('tigera', 0.4756),
#   ('deployments', 0.3663),
#   ('secure', 0.3626),
#   ('securing', 0.3537),
#   ('cloudnative', 0.3505),
#   ('security', 0.346),
#   ('docker', 0.3292),
#   ('azure', 0.3193),
#   ('eks', 0.3173)],
#  [('cvt', 0.5194),
#   ('cardiaq', 0.4702),
#   ('tmvi', 0.4243),
#   ('valve', 0.4042),
#   ('transcatheter', 0.3879),
#   ('heart', 0.3027),
#   ('technologies', 0.2502),
#   ('mitral', 0.2494),
#   ('implantation', 0.2346),
#   ('innovative', 0.1974)],
#  [('tripwire', 0.6173),
#   ('tripwireinc', 0.5987),
#   ('httpwwwtripwirecomstateofsecurity', 0.5059),
#   ('cybersecurity', 0.4748),
#   ('security', 0.3946),
#   ('wwwtripwirecom', 0.3755),
#   ('vulnerability', 0.2862),
#   ('enterprise', 0.2673),
#   ('endpoint', 0.2631),
#   ('enterpriseclass', 0.2619)],
#  [('hyperthyroidism', 0.5982),
#   ('thyroid', 0.5299),
#   ('orbitopathy', 0.4985),
#   ('thyritope', 0.4829),
#   ('autoantibodies', 0.4448),
#   ('graves', 0.4434),
#   ('autoimmune', 0.4151),
#   ('antibodies', 0.3185),
#   ('hormone', 0.2997),
#   ('disease', 0.2799)],
#  [('cellscope', 0.6857),
#   ('otoscope', 0.5624),
#   ('telemedicine', 0.4937),
#   ('smartphone', 0.4409),
#   ('mobile', 0.3774),
#   ('imaging', 0.3558),
#   ('diagnostic', 0.35),
#   ('clinicians', 0.2973),
#   ('technology', 0.2888),
#   ('digital', 0.2793)],
#  [('workforce', 0.5407),
#   ('employees', 0.4307),
#   ('scheduling', 0.4084),
#   ('cloud', 0.3987),
#   ('enterprise', 0.3849),
#   ('employee', 0.3769),
#   ('software', 0.3752),
#   ('demanddriven', 0.3295),
#   ('management', 0.3253),
#   ('labor', 0.3012)],
#  [('syncplicityhttpwwwsyncplicitycom', 0.6755),
#   ('syncplicity', 0.5522),
#   ('syncing', 0.5062),
#   ('synchronization', 0.4863),
#   ('backups', 0.4777),
#   ('backup', 0.4683),
#   ('files', 0.3423),
#   ('sharing', 0.3178),
#   ('storage', 0.2905),
#   ('file', 0.2904)],
#  [('swing', 0.4034),
#   ('swings', 0.3746),
#   ('teachers', 0.3468),
#   ('substitute', 0.292),
#   ('teacher', 0.2836),
#   ('scheduling', 0.2834),
#   ('schools', 0.2721),
#   ('absences', 0.2686),
#   ('students', 0.2493),
#   ('school', 0.229)],
#  [('blockseer', 0.6742),
#   ('blockseers', 0.4961),
#   ('blockchain', 0.4837),
#   ('forensics', 0.3),
#   ('data', 0.2583),
#   ('analytics', 0.258),
#   ('applications', 0.1945),
#   ('patterns', 0.1861),
#   ('visualizations', 0.1812),
#   ('analysis', 0.181)],
#  [('pharmaceuticals', 0.42),
#   ('inhibitor', 0.4085),
#   ('pharmaceutical', 0.403),
#   ('medicines', 0.3237),
#   ('herceptin', 0.3169),
#   ('mundipharma', 0.3133),
#   ('hsp', 0.2803),
#   ('retaspimycin', 0.2679),
#   ('hydrochloride', 0.2653),
#   ('cancer', 0.2508)],
#  [('loglogic', 0.7811),
#   ('log', 0.4112),
#   ('enterprise', 0.3073),
#   ('cloud', 0.2784),
#   ('data', 0.2771),
#   ('scalable', 0.2168),
#   ('security', 0.2039),
#   ('exabyte', 0.2008),
#   ('provider', 0.1988),
#   ('platform', 0.186)],
#  [('junction', 0.4328),
#   ('solar', 0.4065),
#   ('cpv', 0.3581),
#   ('iiiv', 0.2955),
#   ('ventures', 0.2436),
#   ('manufacturer', 0.2301),
#   ('company', 0.2285),
#   ('aslam', 0.2142),
#   ('multijunction', 0.2105),
#   ('headquartered', 0.2047)],
#  [('availability', 0.4392),
#   ('application', 0.4054),
#   ('enterprise', 0.3993),
#   ('applications', 0.3903),
#   ('software', 0.3799),
#   ('automation', 0.368),
#   ('reflectent', 0.3526),
#   ('endusers', 0.3162),
#   ('enduser', 0.2861),
#   ('servers', 0.2851)],
#  [('lumere', 0.5366),
#   ('clinical', 0.4276),
#   ('pharmacists', 0.4252),
#   ('clinicians', 0.4127),
#   ('procured', 0.3499),
#   ('drug', 0.342),
#   ('health', 0.3028),
#   ('researchers', 0.2938),
#   ('strategic', 0.1963),
#   ('organization', 0.1917)],
#  [('astrid', 0.7017),
#   ('tasks', 0.2919),
#   ('social', 0.2744),
#   ('todo', 0.2611),
#   ('organize', 0.2603),
#   ('list', 0.2501),
#   ('share', 0.2306),
#   ('people', 0.2195),
#   ('encouragement', 0.2109),
#   ('ideas', 0.1987)],
#  [('zingbox', 0.5264),
#   ('box', 0.36),
#   ('backyard', 0.3522),
#   ('park', 0.3394),
#   ('bbqs', 0.3104),
#   ('solar', 0.2804),
#   ('karaoke', 0.2754),
#   ('parties', 0.2679),
#   ('tailgating', 0.2644),
#   ('powered', 0.2128)],
#  [('truecommerce', 0.6289),
#   ('edi', 0.4354),
#   ('commerceâ', 0.4051),
#   ('companyâ', 0.2881),
#   ('companies', 0.2819),
#   ('industries', 0.2802),
#   ('retail', 0.2713),
#   ('customers', 0.2688),
#   ('interchange', 0.2647),
#   ('exchange', 0.2591)],
#  [('nsg', 0.6145),
#   ('esports', 0.5571),
#   ('athletes', 0.4155),
#   ('gamers', 0.3863),
#   ('competitors', 0.3515),
#   ('premier', 0.3025),
#   ('careers', 0.2986),
#   ('developing', 0.2688),
#   ('americas', 0.2477),
#   ('fans', 0.2094)],
#  [('divorcesecure', 0.7539),
#   ('divorce', 0.4788),
#   ('clients', 0.3533),
#   ('attorneys', 0.3261),
#   ('collaboration', 0.3172),
#   ('asset', 0.2699),
#   ('services', 0.2497),
#   ('platform', 0.2446),
#   ('manage', 0.2233),
#   ('automation', 0.2025)],
#  [('social', 0.5093),
#   ('instructors', 0.488),
#   ('students', 0.4591),
#   ('learning', 0.327),
#   ('employers', 0.3106),
#   ('connecting', 0.2543),
#   ('platform', 0.2379),
#   ('predominant', 0.0633)],
#  [('creditworthiness', 0.5461),
#   ('consumers', 0.4253),
#   ('adaptive', 0.3802),
#   ('risk', 0.3584),
#   ('proprietary', 0.3303),
#   ('pricing', 0.3066),
#   ('realtime', 0.1729),
#   ('ascend', 0.1544),
#   ('process', 0.1368),
#   ('prove', 0.1236)],
#  [('advertising', 0.4661),
#   ('market', 0.4004),
#   ('nexage', 0.4002),
#   ('mobile', 0.3693),
#   ('exchangebased', 0.3486),
#   ('customers', 0.3415),
#   ('markets', 0.3411),
#   ('publishers', 0.3348),
#   ('exchanges', 0.3294),
#   ('buyers', 0.3293)],
#  [('biome', 0.652),
#   ('plants', 0.4398),
#   ('planets', 0.4388),
#   ('nature', 0.4008),
#   ('machines', 0.3239),
#   ('machine', 0.2966),
#   ('filters', 0.215),
#   ('air', 0.2083),
#   ('natural', 0.2027),
#   ('purifier', 0.2025)],
#  [('udacity', 0.4973),
#   ('udacitys', 0.4754),
#   ('courses', 0.4043),
#   ('developer', 0.3424),
#   ('education', 0.3031),
#   ('development', 0.2789),
#   ('programming', 0.2761),
#   ('teach', 0.2726),
#   ('tech', 0.2718),
#   ('learning', 0.2689)],
#  [('equitysim', 0.5607),
#   ('education', 0.4393),
#   ('educational', 0.4343),
#   ('curriculum', 0.3959),
#   ('simulations', 0.3857),
#   ('classrooms', 0.3552),
#   ('markets', 0.3227),
#   ('students', 0.3174),
#   ('engaging', 0.3073),
#   ('financial', 0.2967)],
#  [('prints', 0.5188),
#   ('printing', 0.5074),
#   ('printer', 0.4959),
#   ('materials', 0.4031),
#   ('parts', 0.3725),
#   ('fiber', 0.3684),
#   ('carbon', 0.3445),
#   ('reinforced', 0.3313),
#   ('objects', 0.2879),
#   ('stronger', 0.2847)],
#  [('nanoproteomics', 0.6025),
#   ('nanofluidic', 0.4817),
#   ('biosciences', 0.478),
#   ('capillarybased', 0.3469),
#   ('sciences', 0.3202),
#   ('ultrasensitive', 0.3148),
#   ('proteins', 0.3142),
#   ('cell', 0.2958),
#   ('biological', 0.2752),
#   ('protein', 0.2694)],
#  [('spatial', 0.5192),
#   ('data', 0.4243),
#   ('cities', 0.3484),
#   ('ethnographic', 0.344),
#   ('social', 0.3364),
#   ('research', 0.3225),
#   ('technology', 0.3212),
#   ('earth', 0.3144),
#   ('surrounding', 0.3046),
#   ('information', 0.2921)],
#  [('uparts', 0.5619),
#   ('software', 0.348),
#   ('insurance', 0.3465),
#   ('procurement', 0.3316),
#   ('aftermarket', 0.3309),
#   ('repair', 0.3229),
#   ('oem', 0.3169),
#   ('applications', 0.2952),
#   ('suppliers', 0.2948),
#   ('auto', 0.278)],
#  [('zillows', 0.696),
#   ('zillow', 0.6511),
#   ('zillowcom', 0.4507),
#   ('homes', 0.4039),
#   ('mortgages', 0.3895),
#   ('homeowners', 0.384),
#   ('mortgage', 0.3747),
#   ('renters', 0.2973),
#   ('rentals', 0.2862),
#   ('buyers', 0.2854)],
#  [('catalog', 0.5623),
#   ('data', 0.5382),
#   ('datafluent', 0.5044),
#   ('datadriven', 0.469),
#   ('market', 0.331),
#   ('company', 0.3242),
#   ('salesforce', 0.3226),
#   ('alation', 0.3223),
#   ('ventures', 0.3219),
#   ('organizations', 0.2936)],
#  [('tinypulse', 0.5959),
#   ('feedback', 0.3744),
#   ('tool', 0.3256),
#   ('easytouse', 0.3107),
#   ('employee', 0.3102),
#   ('leaders', 0.2738),
#   ('company', 0.2365),
#   ('data', 0.2028),
#   ('perform', 0.1868),
#   ('actionable', 0.1865)],
#  [('copia', 0.3957),
#   ('nonprofits', 0.3653),
#   ('caterers', 0.3607),
#   ('feeding', 0.3557),
#   ('hunger', 0.3551),
#   ('logistics', 0.3422),
#   ('scarcity', 0.3331),
#   ('food', 0.3228),
#   ('landfills', 0.3226),
#   ('businesses', 0.3125)],
#  [('interviews', 0.5481),
#   ('interview', 0.5081),
#   ('interviewing', 0.5017),
#   ('karat', 0.4426),
#   ('karats', 0.4229),
#   ('engineers', 0.3546),
#   ('hiring', 0.3479),
#   ('engineering', 0.3153),
#   ('software', 0.2943),
#   ('dataset', 0.2734)],
#  [('media', 0.4375),
#   ('consumer', 0.4177),
#   ('consumption', 0.3933),
#   ('accountability', 0.3769),
#   ('scarcity', 0.3532),
#   ('attention', 0.344),
#   ('digital', 0.3273),
#   ('invisibly', 0.3175),
#   ('ecosystem', 0.2921),
#   ('improved', 0.1507)],
#  [('debt', 0.4708),
#   ('futurefuel', 0.4195),
#   ('exgoogler', 0.4117),
#   ('benefits', 0.3436),
#   ('future', 0.3403),
#   ('employers', 0.3311),
#   ('student', 0.2821),
#   ('empowers', 0.2797),
#   ('crush', 0.19),
#   ('designed', 0.179)],
#  [('breakthroughs', 0.4672),
#   ('medicines', 0.4109),
#   ('biosciences', 0.3889),
#   ('innovation', 0.3544),
#   ('innovations', 0.3498),
#   ('cures', 0.2868),
#   ('healthcare', 0.2859),
#   ('clinically', 0.2781),
#   ('patients', 0.2749),
#   ('regulatory', 0.2702)],
#  [('changecoin', 0.739),
#   ('changetip', 0.4386),
#   ('micropayment', 0.41),
#   ('payment', 0.3769),
#   ('financial', 0.3221),
#   ('social', 0.2769),
#   ('transforming', 0.2712),
#   ('redefining', 0.2674),
#   ('exchange', 0.2628),
#   ('internet', 0.2615)],
#  [('peopleai', 0.5636),
#   ('customers', 0.4867),
#   ('marketing', 0.4636),
#   ('customer', 0.4368),
#   ('ai', 0.4143),
#   ('analytics', 0.4105),
#   ('sales', 0.4097),
#   ('marketers', 0.3864),
#   ('enterprise', 0.3814),
#   ('success', 0.3405)],
#  [('technologies', 0.4369),
#   ('transportation', 0.3028),
#   ('storage', 0.2676),
#   ('massachusetts', 0.2557),
#   ('systems', 0.2497),
#   ('energy', 0.221),
#   ('company', 0.2008),
#   ('applications', 0.1869),
#   ('builds', 0.1842),
#   ('grid', 0.1482)],
#  [('babyage', 0.752),
#   ('infant', 0.5511),
#   ('toddler', 0.441),
#   ('retailer', 0.4342),
#   ('juvenile', 0.3744),
#   ('products', 0.2774),
#   ('online', 0.2293)],
#  [('stylehive', 0.7069),
#   ('stylehives', 0.667),
#   ('styles', 0.4916),
#   ('style', 0.4175),
#   ('bookmarking', 0.3722),
#   ('social', 0.3383),
#   ('tagged', 0.2907),
#   ('promote', 0.2775),
#   ('shopping', 0.2523),
#   ('follow', 0.2517)],
#  [('trash', 0.4382),
#   ('editing', 0.4015),
#   ('predictive', 0.3767),
#   ('video', 0.3276),
#   ('offers', 0.0718)],
#  [('galleryplayer', 0.7822),
#   ('galleryplayers', 0.7386),
#   ('viewing', 0.4101),
#   ('displays', 0.3912),
#   ('presentation', 0.3857),
#   ('photographic', 0.3774),
#   ('artwork', 0.3754),
#   ('hdtvs', 0.3745),
#   ('museum', 0.3503),
#   ('arts', 0.3497)],
#  [('bound', 0.4287),
#   ('leveraging', 0.4115),
#   ('profiling', 0.4051),
#   ('audience', 0.3911),
#   ('ventures', 0.3529),
#   ('personalization', 0.35),
#   ('customers', 0.3166),
#   ('linkedin', 0.3046),
#   ('marketers', 0.2971),
#   ('personalized', 0.2969)],
#  [('rad', 0.5507),
#   ('manufacturers', 0.4372),
#   ('headquartered', 0.384),
#   ('manufacturing', 0.3758),
#   ('llc', 0.3699),
#   ('company', 0.3686),
#   ('industry', 0.3286),
#   ('technologies', 0.3107),
#   ('enterprises', 0.3097),
#   ('electronics', 0.2555)],
#  [('oschool', 0.5601),
#   ('lgbtqfriendly', 0.4194),
#   ('chat', 0.3761),
#   ('shamefree', 0.371),
#   ('desires', 0.3666),
#   ('sexual', 0.3458),
#   ('streaming', 0.336),
#   ('education', 0.3284),
#   ('judgmentfree', 0.2882),
#   ('communicate', 0.2797)],
#  [('onekloud', 0.535),
#   ('cloud', 0.4876),
#   ('azure', 0.442),
#   ('infrastructure', 0.3176),
#   ('spending', 0.3172),
#   ('aws', 0.2823),
#   ('quotas', 0.2739),
#   ('costs', 0.2614),
#   ('budget', 0.2539),
#   ('accountability', 0.2491)],
#  [('eyefi', 0.579),
#   ('camera', 0.3727),
#   ('cameras', 0.3432),
#   ('wireless', 0.3374),
#   ('wirelessly', 0.3227),
#   ('iphone', 0.2962),
#   ('mobile', 0.288),
#   ('iphoneipad', 0.2842),
#   ('uploads', 0.2785),
#   ('distributors', 0.2709)],
#  [('realself', 0.6294),
#   ('cosmetic', 0.4264),
#   ('aesthetic', 0.3642),
#   ('market', 0.3382),
#   ('medical', 0.3363),
#   ('clinicians', 0.3293),
#   ('surgery', 0.3286),
#   ('doctors', 0.3038),
#   ('experiences', 0.3036),
#   ('skin', 0.291)],
#  [('synthesize', 0.4913),
#   ('fermentation', 0.4707),
#   ('microorganisms', 0.3729),
#   ('gene', 0.3714),
#   ('metabolic', 0.3565),
#   ('verdezyne', 0.3539),
#   ('petrochemical', 0.3531),
#   ('biological', 0.3309),
#   ('computational', 0.3096),
#   ('pathways', 0.2941)],
#  [('apploi', 0.5526),
#   ('applications', 0.4553),
#   ('geolocation', 0.3961),
#   ('mobile', 0.3711),
#   ('hiring', 0.3348),
#   ('kiosks', 0.3274),
#   ('applicants', 0.315),
#   ('employers', 0.3094),
#   ('instore', 0.2608),
#   ('jobs', 0.2531)],
#  [('funplus', 0.5983),
#   ('esports', 0.4858),
#   ('games', 0.4676),
#   ('gaming', 0.4461),
#   ('entertainment', 0.4027),
#   ('sports', 0.3776),
#   ('global', 0.3776),
#   ('game', 0.3695),
#   ('slg', 0.3643),
#   ('teams', 0.3534)],
#  [('accend', 0.5294),
#   ('incorporated', 0.3806),
#   ('software', 0.3715),
#   ('enterprise', 0.3499),
#   ('drilling', 0.3078),
#   ('company', 0.2692),
#   ('industry', 0.2587),
#   ('texas', 0.243),
#   ('application', 0.2374),
#   ('austin', 0.2347)],
#  [('mesocoat', 0.7447),
#   ('coatings', 0.5381),
#   ('company', 0.2215),
#   ('applications', 0.2155),
#   ('aerospace', 0.1998),
#   ('infrastructure', 0.1735),
#   ('development', 0.1551),
#   ('startup', 0.1227),
#   ('roads', 0.0983),
#   ('new', 0.0891)],
#  [('musiquest', 0.762),
#   ('music', 0.4514),
#   ('musical', 0.3975),
#   ('platform', 0.2523),
#   ('developer', 0.236),
#   ('content', 0.2084),
#   ('application', 0.1989),
#   ('buzzwords', 0.1879),
#   ('discover', 0.1678),
#   ('passion', 0.16)],
#  [('construction', 0.4779),
#   ('ai', 0.4338),
#   ('computational', 0.4209),
#   ('engineers', 0.4205),
#   ('engineering', 0.402),
#   ('alice', 0.3807),
#   ('software', 0.3496),
#   ('interactive', 0.3433),
#   ('schedules', 0.3407),
#   ('managers', 0.3144)],
#  [('ibis', 0.5244),
#   ('enterprisedefined', 0.3025),
#   ('energy', 0.2571),
#   ('networks', 0.2478),
#   ('electronics', 0.2414),
#   ('enterprises', 0.2389),
#   ('investment', 0.2068),
#   ('consumption', 0.2048),
#   ('enables', 0.2039),
#   ('mobile', 0.1999)],
#  [('adtheorent', 0.6794),
#   ('advertisers', 0.4942),
#   ('advertising', 0.4759),
#   ('wwwadtheorentcom', 0.3923),
#   ('attribution', 0.3004),
#   ('predictive', 0.2914),
#   ('provider', 0.2852),
#   ('audiences', 0.2837),
#   ('brands', 0.2663),
#   ('digital', 0.2459)],
#  [('brat', 0.6388),
#   ('teenleaning', 0.382),
#   ('industry', 0.326),
#   ('technology', 0.3231),
#   ('digital', 0.3166),
#   ('company', 0.3115),
#   ('production', 0.2906),
#   ('operates', 0.2446)],
#  [('uniquesound', 0.6402),
#   ('creatives', 0.4294),
#   ('composers', 0.3961),
#   ('designers', 0.3524),
#   ('music', 0.3314),
#   ('showcase', 0.3287),
#   ('techstars', 0.3184),
#   ('supervisors', 0.2904),
#   ('directors', 0.2865),
#   ('companies', 0.2656)],
#  [('xtrachef', 0.6373),
#   ('foodservice', 0.5212),
#   ('restaurant', 0.4023),
#   ('platform', 0.2858),
#   ('cloudbased', 0.2655),
#   ('data', 0.2559),
#   ('leveraging', 0.2435),
#   ('machine', 0.227),
#   ('backofhouse', 0.2246),
#   ('automation', 0.2242)],
#  [('bonfire', 0.465),
#   ('friendships', 0.462),
#   ('experiences', 0.4306),
#   ('adventure', 0.4243),
#   ('experience', 0.4017),
#   ('game', 0.3911),
#   ('fellowship', 0.3776),
#   ('exploration', 0.3634),
#   ('passion', 0.3625),
#   ('players', 0.3414)],
#  [('vertical', 0.472),
#   ('interconnect', 0.4207),
#   ('circuits', 0.4111),
#   ('semiconductor', 0.3303),
#   ('lowcost', 0.3099),
#   ('highspeedhighdensity', 0.3074),
#   ('packaging', 0.272),
#   ('supplier', 0.2683),
#   ('components', 0.2679),
#   ('manufacture', 0.2368)],
#  [('lithography', 0.5897),
#   ('ebeam', 0.3188),
#   ('photomask', 0.2881),
#   ('wafer', 0.2847),
#   ('mask', 0.2219),
#   ('designs', 0.2195),
#   ('soc', 0.2046),
#   ('writetimes', 0.1669),
#   ('ds', 0.1635),
#   ('circuits', 0.1583)],
#  [('ael', 0.5461),
#   ('laboratories', 0.5103),
#   ('laboratory', 0.5016),
#   ('mpl', 0.4223),
#   ('memphis', 0.3992),
#   ('medical', 0.3762),
#   ('hospitals', 0.371),
#   ('physician', 0.364),
#   ('esoteric', 0.3419),
#   ('industry', 0.3155)],
#  [('prospx', 0.7171),
#   ('sales', 0.3618),
#   ('insurance', 0.2779),
#   ('commercial', 0.2368),
#   ('brokers', 0.2228),
#   ('customer', 0.215),
#   ('process', 0.2094),
#   ('saasbased', 0.2009),
#   ('industry', 0.1942),
#   ('processes', 0.1827)],
#  [('nanolaminated', 0.4572),
#   ('modumetal', 0.4403),
#   ('metals', 0.4187),
#   ('alloys', 0.4075),
#   ('electrochemical', 0.3859),
#   ('corrosion', 0.382),
#   ('metal', 0.3237),
#   ('coatings', 0.3195),
#   ('materials', 0.2984),
#   ('material', 0.2348)],
#  [('avatar', 0.4304),
#   ('virtual', 0.3849),
#   ('worlds', 0.3629),
#   ('world', 0.3428),
#   ('mars', 0.3135),
#   ('platform', 0.3112),
#   ('founded', 0.2957),
#   ('global', 0.292),
#   ('hashimoto', 0.2819),
#   ('reality', 0.2692)],
#  [('steelhouse', 0.5594),
#   ('advertising', 0.5323),
#   ('advertisers', 0.4946),
#   ('ads', 0.4827),
#   ('marketers', 0.4521),
#   ('campaigns', 0.3454),
#   ('brands', 0.3293),
#   ('suite', 0.3283),
#   ('companies', 0.3004),
#   ('innovator', 0.2931)],
#  [('twitter', 0.4725),
#   ('gremlin', 0.4594),
#   ('gremlinsocialcom', 0.3818),
#   ('analytics', 0.3743),
#   ('facebook', 0.3712),
#   ('guardian', 0.3612),
#   ('social', 0.3604),
#   ('enterprise', 0.3532),
#   ('branded', 0.3255),
#   ('reports', 0.3251)],
#  [('restaurant', 0.5314),
#   ('restaurants', 0.497),
#   ('whentomanage', 0.3756),
#   ('clients', 0.3197),
#   ('software', 0.3125),
#   ('management', 0.2947),
#   ('scheduling', 0.2899),
#   ('inventory', 0.2892),
#   ('managers', 0.2767),
#   ('webbased', 0.2751)],
#  [('bonfaire', 0.6303),
#   ('retail', 0.3668),
#   ('shoes', 0.3434),
#   ('handbags', 0.3327),
#   ('shop', 0.3113),
#   ('products', 0.3038),
#   ('showrooms', 0.3014),
#   ('luxury', 0.301),
#   ('preorder', 0.2911),
#   ('showroom', 0.2784)],
#  [('strala', 0.6361),
#   ('saas', 0.4099),
#   ('touchpoint', 0.3773),
#   ('touchpoints', 0.3392),
#   ('personalization', 0.3297),
#   ('crm', 0.328),
#   ('platform', 0.3197),
#   ('data', 0.3078),
#   ('organizations', 0.2899),
#   ('platforms', 0.2836)],
#  [('seedinvest', 0.784),
#   ('crowdfunding', 0.4642),
#   ('investors', 0.4367),
#   ('invests', 0.3858),
#   ('investment', 0.3357),
#   ('syndicate', 0.2878),
#   ('equity', 0.2412),
#   ('startup', 0.2066),
#   ('vetted', 0.1687),
#   ('network', 0.1654)],
#  [('nucurrent', 0.5561),
#   ('antennas', 0.4157),
#   ('antenna', 0.3672),
#   ('wireless', 0.2516),
#   ('consortium', 0.194),
#   ('qi', 0.187),
#   ('power', 0.1712),
#   ('oems', 0.1617),
#   ('patented', 0.1561),
#   ('device', 0.1553)],
#  [('alphaeon', 0.6468),
#   ('commerce', 0.3213),
#   ('company', 0.3161),
#   ('wwwalphaeoncom', 0.3107),
#   ('wellness', 0.3078),
#   ('consumer', 0.3068),
#   ('selfpay', 0.3055),
#   ('corporation', 0.2989),
#   ('healthcare', 0.2785),
#   ('partnership', 0.2754)],
#  [('cyber', 0.4495),
#   ('security', 0.3791),
#   ('adapt', 0.3389),
#   ('networkssince', 0.3191),
#   ('enterprise', 0.3168),
#   ('safeguard', 0.3013),
#   ('threats', 0.2864),
#   ('threat', 0.2811),
#   ('digital', 0.281),
#   ('protecting', 0.2748)],
#  [('lockpath', 0.554),
#   ('auditready', 0.4139),
#   ('compliance', 0.4134),
#   ('audit', 0.3918),
#   ('security', 0.3791),
#   ('infosec', 0.3611),
#   ('regulatory', 0.3243),
#   ('enterprise', 0.3076),
#   ('enterprises', 0.3049),
#   ('applications', 0.3016)],
#  [('checkout', 0.6181),
#   ('monetization', 0.4857),
#   ('billing', 0.4758),
#   ('commerce', 0.4607),
#   ('payments', 0.4035),
#   ('businesses', 0.354),
#   ('sales', 0.3186),
#   ('global', 0.2974),
#   ('delivering', 0.2925),
#   ('merchandising', 0.2834)],
#  [('vineti', 0.4146),
#   ('biopharmaceutical', 0.3915),
#   ('cloudbased', 0.3506),
#   ('providers', 0.3464),
#   ('logistics', 0.3219),
#   ('medicine', 0.3212),
#   ('pharmaceutical', 0.3132),
#   ('clinic', 0.303),
#   ('clinical', 0.2908),
#   ('medical', 0.2852)],
#  [('tenants', 0.4693),
#   ('avail', 0.4348),
#   ('rentals', 0.4338),
#   ('landlords', 0.4284),
#   ('rental', 0.3999),
#   ('rent', 0.3774),
#   ('leases', 0.3682),
#   ('platform', 0.3459),
#   ('diy', 0.3025),
#   ('experience', 0.2753)],
#  [('fortis', 0.6559),
#   ('therapeutics', 0.4404),
#   ('biotech', 0.3682),
#   ('immunooncology', 0.3481),
#   ('therapies', 0.2966),
#   ('prostate', 0.2767),
#   ('antibody', 0.2739),
#   ('myeloma', 0.2677),
#   ('ucsf', 0.2506),
#   ('cancer', 0.245)],
#  [('gogii', 0.6671),
#   ('textplus', 0.486),
#   ('mobile', 0.3832),
#   ('ios', 0.3481),
#   ('android', 0.3107),
#   ('text', 0.3105),
#   ('marina', 0.2302),
#   ('communications', 0.2288),
#   ('application', 0.2269),
#   ('service', 0.1892)],
#  [('gifscom', 0.6853),
#   ('video', 0.3573),
#   ('edit', 0.2809),
#   ('online', 0.223),
#   ('best', 0.1725),
#   ('place', 0.1379)],
#  [('bizblastcom', 0.7351),
#   ('ecommerce', 0.5044),
#   ('businesstoconsumer', 0.3812),
#   ('businesses', 0.3667),
#   ('ebusiness', 0.3653),
#   ('merchants', 0.3584),
#   ('affiliate', 0.3066),
#   ('consulting', 0.294),
#   ('products', 0.2618),
#   ('web', 0.2495)],
#  [('forum', 0.4532),
#   ('industry', 0.4252),
#   ('manufactures', 0.4113),
#   ('company', 0.3837),
#   ('technologies', 0.362),
#   ('construction', 0.3087),
#   ('products', 0.2912),
#   ('drilling', 0.2467),
#   ('houston', 0.2303),
#   ('services', 0.2245)],
#  [('earshot', 0.7004),
#   ('earshots', 0.667),
#   ('decibel', 0.4095),
#   ('realtime', 0.3764),
#   ('media', 0.304),
#   ('marketing', 0.2763),
#   ('detection', 0.2435),
#   ('relevancy', 0.2404),
#   ('level', 0.2293),
#   ('precisionbased', 0.2245)],
#  [('aptegrity', 0.5929),
#   ('globix', 0.3868),
#   ('ecommerce', 0.3673),
#   ('applications', 0.3393),
#   ('company', 0.3151),
#   ('headquartered', 0.3063),
#   ('corporation', 0.3061),
#   ('application', 0.294),
#   ('businesses', 0.2749),
#   ('organizations', 0.2608)],
#  [('tnc', 0.6289),
#   ('google', 0.3392),
#   ('provider', 0.3014),
#   ('korea', 0.2913),
#   ('company', 0.2796),
#   ('blogging', 0.2728),
#   ('acquired', 0.2016),
#   ('platform', 0.1999),
#   ('based', 0.159),
#   ('south', 0.1338)],
#  [('werecover', 0.4966),
#   ('addiction', 0.4941),
#   ('search', 0.3242),
#   ('treatment', 0.2812),
#   ('resources', 0.2478),
#   ('transparent', 0.0788),
#   ('engine', 0.0461)],
#  [('grouper', 0.6892),
#   ('groupers', 0.6805),
#   ('groups', 0.4735),
#   ('club', 0.3877),
#   ('members', 0.3811),
#   ('drinks', 0.3659),
#   ('organizes', 0.3613),
#   ('team', 0.329),
#   ('social', 0.32),
#   ('friends', 0.3067)],
#  [('mobile', 0.4979),
#   ('catalyst', 0.4012),
#   ('entertainment', 0.3996),
#   ('music', 0.3676),
#   ('innovative', 0.3543),
#   ('media', 0.3465),
#   ('consumers', 0.3297),
#   ('innovations', 0.3285),
#   ('devices', 0.3201),
#   ('manufacturers', 0.3126)],
#  [('vocalocity', 0.6014),
#   ('vocalocitys', 0.5798),
#   ('voip', 0.5197),
#   ('voice', 0.4821),
#   ('pbx', 0.4429),
#   ('businesses', 0.3155),
#   ('business', 0.31),
#   ('protocol', 0.3032),
#   ('communication', 0.3031),
#   ('phone', 0.2882)],
#  [('testai', 0.5476),
#   ('testing', 0.462),
#   ('tests', 0.4311),
#   ('apps', 0.4204),
#   ('test', 0.3809),
#   ('agile', 0.3705),
#   ('app', 0.3673),
#   ('automation', 0.3486),
#   ('aipowered', 0.3258),
#   ('software', 0.315)],
#  [('youbeauty', 0.6879),
#   ('personalized', 0.3457),
#   ('commerce', 0.3379),
#   ('brand', 0.3226),
#   ('brands', 0.3119),
#   ('data', 0.3054),
#   ('consumer', 0.2693),
#   ('digital', 0.2454),
#   ('proprietary', 0.2323),
#   ('company', 0.2199)],
#  [('telemedicine', 0.6187),
#   ('avizia', 0.5161),
#   ('software', 0.3533),
#   ('medical', 0.3504),
#   ('cisco', 0.3171),
#   ('collaborative', 0.3138),
#   ('workflow', 0.3044),
#   ('patients', 0.3028),
#   ('consultations', 0.2975),
#   ('professionals', 0.2938)],
#  [('alchemy', 0.6566),
#   ('cosmetic', 0.4701),
#   ('clinics', 0.4371),
#   ('treatments', 0.3825),
#   ('injectable', 0.3457),
#   ('brand', 0.2123),
#   ('delivers', 0.211),
#   ('quality', 0.1527),
#   ('highest', 0.0159)],
#  [('payroll', 0.5355),
#   ('contractors', 0.4522),
#   ('wage', 0.441),
#   ('gig', 0.3834),
#   ('pay', 0.3833),
#   ('businesses', 0.3303),
#   ('visage', 0.2409),
#   ('manage', 0.1849),
#   ('pivot', 0.18),
#   ('independent', 0.0992)],
#  [('sensory', 0.4771),
#   ('technologies', 0.4127),
#   ('audio', 0.4121),
#   ('voice', 0.3442),
#   ('electronics', 0.3392),
#   ('biometric', 0.3275),
#   ('controls', 0.3071),
#   ('products', 0.3007),
#   ('manufacturers', 0.2934),
#   ('robotic', 0.2883)],
#  [('caregivers', 0.6068),
#   ('care', 0.4585),
#   ('mobile', 0.415),
#   ('app', 0.4125),
#   ('checklists', 0.4057),
#   ('kindly', 0.3534),
#   ('manage', 0.3499),
#   ('review', 0.3195),
#   ('loved', 0.3183),
#   ('payments', 0.2856)],
#  [('sanovia', 0.5497),
#   ('pharmaceutical', 0.3817),
#   ('decisionmaking', 0.3736),
#   ('corporation', 0.3152),
#   ('workflow', 0.3086),
#   ('company', 0.3066),
#   ('management', 0.306),
#   ('automated', 0.3045),
#   ('fraud', 0.2959),
#   ('services', 0.2728)],
#  [('cryptek', 0.7378),
#   ('secure', 0.3126),
#   ('llc', 0.2703),
#   ('company', 0.259),
#   ('nanotronics', 0.2377),
#   ('corp', 0.2327),
#   ('companies', 0.2289),
#   ('providers', 0.2183),
#   ('founded', 0.1971),
#   ('manufacturers', 0.1969)],
#  [('accessline', 0.5711),
#   ('telanetix', 0.399),
#   ('onestop', 0.3256),
#   ('businesses', 0.2954),
#   ('company', 0.2952),
#   ('customers', 0.2864),
#   ('access', 0.2845),
#   ('communications', 0.2833),
#   ('services', 0.2777),
#   ('business', 0.2767)],
#  [('sourceress', 0.698),
#   ('recruiter', 0.4411),
#   ('hiring', 0.3924),
#   ('ai', 0.3465),
#   ('managers', 0.3364),
#   ('researchers', 0.333),
#   ('venture', 0.3245),
#   ('openai', 0.2927),
#   ('jobs', 0.2914),
#   ('candidates', 0.2836)],
#  [('affiliate', 0.5374),
#   ('yub', 0.4652),
#   ('retailers', 0.3903),
#   ('merchants', 0.3736),
#   ('purchases', 0.3487),
#   ('instore', 0.3221),
#   ('shoppers', 0.304),
#   ('consumers', 0.2812),
#   ('network', 0.2589),
#   ('offline', 0.2582)],
#  [('activevideo', 0.6289),
#   ('webmedia', 0.5873),
#   ('tv', 0.3801),
#   ('platform', 0.3137),
#   ('patents', 0.3025),
#   ('internet', 0.2799),
#   ('programming', 0.2311),
#   ('experience', 0.2083),
#   ('infrastructure', 0.2033),
#   ('ondemand', 0.1777)],
#  [('kazeon', 0.4451),
#   ('ediscoverylitigation', 0.4166),
#   ('ediscovery', 0.3782),
#   ('storage', 0.3276),
#   ('archival', 0.3152),
#   ('backup', 0.3049),
#   ('service', 0.2825),
#   ('services', 0.2817),
#   ('electronic', 0.2733),
#   ('providers', 0.2725)],
#  [('retargeting', 0.5506),
#   ('advertising', 0.4432),
#   ('native', 0.3229),
#   ('customers', 0.322),
#   ('inventory', 0.3002),
#   ('platform', 0.2831),
#   ('purchase', 0.2808),
#   ('intent', 0.2433),
#   ('global', 0.2292),
#   ('return', 0.1922)],
#  [('lendkey', 0.7252),
#   ('lending', 0.5966),
#   ('loan', 0.5389),
#   ('financial', 0.3253),
#   ('businesses', 0.1939),
#   ('customer', 0.1828),
#   ('service', 0.175),
#   ('company', 0.1687),
#   ('institutions', 0.1649),
#   ('digital', 0.1603)],
#  [('owlet', 0.5704),
#   ('monitor', 0.3657),
#   ('infants', 0.2842),
#   ('childs', 0.2227),
#   ('parent', 0.2053),
#   ('parents', 0.1901),
#   ('vital', 0.1869),
#   ('alert', 0.1841),
#   ('health', 0.1662),
#   ('heart', 0.1574)],
#  [('lender', 0.4971),
#   ('mortgage', 0.4536),
#   ('financing', 0.4283),
#   ('fullstack', 0.4246),
#   ('funding', 0.3854),
#   ('loan', 0.3744),
#   ('financial', 0.3416),
#   ('google', 0.2921),
#   ('goldman', 0.2839),
#   ('spotify', 0.2731)],
#  [('corneal', 0.5125),
#   ('lasik', 0.4521),
#   ('cornea', 0.4312),
#   ('keratoconus', 0.4149),
#   ('keraflex', 0.3872),
#   ('ophthalmic', 0.3597),
#   ('refractive', 0.3507),
#   ('avedro', 0.3506),
#   ('incision', 0.2864),
#   ('surgery', 0.2751)],
#  [('ripple', 0.5711),
#   ('dairyfree', 0.5609),
#   ('dairy', 0.5183),
#   ('milk', 0.4626),
#   ('creamy', 0.3878),
#   ('almond', 0.3664),
#   ('soy', 0.3641),
#   ('calcium', 0.348),
#   ('protein', 0.3247),
#   ('sugar', 0.3089)],
#  [('profitline', 0.6391),
#   ('wireline', 0.4364),
#   ('telecom', 0.3696),
#   ('tlm', 0.3153),
#   ('invoices', 0.306),
#   ('enterprisea', 0.2919),
#   ('mydevicemanager', 0.2904),
#   ('company', 0.2859),
#   ('mytelcomanager', 0.2855),
#   ('carrier', 0.2742)],
#  [('financing', 0.4418),
#   ('projects', 0.4057),
#   ('pricing', 0.3962),
#   ('owners', 0.3819),
#   ('fees', 0.3771),
#   ('construction', 0.3588),
#   ('manufacturer', 0.339),
#   ('executives', 0.3364),
#   ('portfolio', 0.3347),
#   ('utility', 0.3154)],
#  [('vudu', 0.5935),
#   ('hdtvs', 0.3345),
#   ('tv', 0.3118),
#   ('remotes', 0.2912),
#   ('box', 0.2657),
#   ('digital', 0.2652),
#   ('internet', 0.251),
#   ('distributors', 0.2436),
#   ('company', 0.2196),
#   ('products', 0.2142)],
#  [('vurvs', 0.7078),
#   ('vurv', 0.7032),
#   ('software', 0.3062),
#   ('softwareasaservice', 0.2982),
#   ('recruitment', 0.2922),
#   ('workforce', 0.2651),
#   ('tools', 0.2518),
#   ('management', 0.2234),
#   ('onboarding', 0.2125),
#   ('companys', 0.2125)],
#  [('expenses', 0.4436),
#   ('expenditures', 0.3846),
#   ('billing', 0.3787),
#   ('roberts', 0.3736),
#   ('financial', 0.3707),
#   ('market', 0.321),
#   ('data', 0.3184),
#   ('costs', 0.315),
#   ('organizations', 0.2652),
#   ('trgs', 0.2433)],
#  [('zebit', 0.5446),
#   ('financing', 0.4404),
#   ('payments', 0.423),
#   ('loans', 0.4094),
#   ('credit', 0.3843),
#   ('interestfree', 0.3731),
#   ('marketplace', 0.3271),
#   ('consumers', 0.3154),
#   ('consumer', 0.3126),
#   ('purchase', 0.3087)],
#  [('advertising', 0.4369),
#   ('technologydriven', 0.3742),
#   ('platform', 0.3126),
#   ('consumer', 0.3074),
#   ('publishers', 0.3041),
#   ('technology', 0.2918),
#   ('ad', 0.2889),
#   ('audience', 0.2845),
#   ('attention', 0.2768),
#   ('benefit', 0.2644)],
#  [('caregain', 0.4769),
#   ('bankconnect', 0.3907),
#   ('cardconnect', 0.3682),
#   ('healthcare', 0.3431),
#   ('banks', 0.3251),
#   ('consulting', 0.2794),
#   ('financial', 0.2762),
#   ('application', 0.273),
#   ('integrated', 0.2688),
#   ('custodians', 0.267)],
#  [('yesvideocom', 0.5458),
#   ('yesvideo', 0.5018),
#   ('provider', 0.454),
#   ('services', 0.3169),
#   ('usa', 0.3151),
#   ('legacyrepubliccom', 0.3126),
#   ('service', 0.3065),
#   ('media', 0.305),
#   ('canada', 0.2945),
#   ('digitization', 0.2945)],
#  [('hiq', 0.4789),
#   ('analytics', 0.4706),
#   ('labs', 0.4024),
#   ('wwwhiqlabscom', 0.3666),
#   ('workforce', 0.3486),
#   ('enterprise', 0.3054),
#   ('data', 0.2815),
#   ('employees', 0.2765),
#   ('datadriven', 0.2684),
#   ('development', 0.2457)],
#  [('bluespace', 0.6214),
#   ('smartxd', 0.4729),
#   ('applications', 0.3442),
#   ('security', 0.3324),
#   ('application', 0.3312),
#   ('wwwbluespacecom', 0.3142),
#   ('cyber', 0.3058),
#   ('framework', 0.2649),
#   ('enforcement', 0.2332),
#   ('databases', 0.2317)],
#  [('box', 0.5855),
#   ('cloud', 0.4004),
#   ('storage', 0.2968),
#   ('platform', 0.2861),
#   ('service', 0.2534),
#   ('content', 0.242),
#   ('business', 0.2211),
#   ('sharing', 0.2082),
#   ('securely', 0.199),
#   ('custom', 0.198)],
#  [('pharmaceuticals', 0.4185),
#   ('biocompatible', 0.3588),
#   ('vivo', 0.3566),
#   ('mucosal', 0.3391),
#   ('formulations', 0.3365),
#   ('mucus', 0.3232),
#   ('pharmacokinetics', 0.3201),
#   ('kala', 0.3008),
#   ('kalas', 0.2798),
#   ('treatments', 0.2783)],
#  [('founded', 0.4881),
#   ('fancreds', 0.3732),
#   ('fans', 0.3573),
#   ('sports', 0.3492),
#   ('members', 0.3474),
#   ('mission', 0.3196),
#   ('hossein', 0.3139),
#   ('worlds', 0.3101),
#   ('kash', 0.2982),
#   ('razzaghi', 0.2852)],
#  [('ticketfly', 0.6325),
#   ('ticketweb', 0.5218),
#   ('ticketing', 0.4478),
#   ('tickets', 0.402),
#   ('eventbrite', 0.3707),
#   ('promoters', 0.3632),
#   ('festival', 0.3586),
#   ('venues', 0.3529),
#   ('marketing', 0.2963),
#   ('companies', 0.2891)],
#  [('tonomi', 0.5116),
#   ('cloud', 0.3783),
#   ('enterprise', 0.3607),
#   ('infrastructure', 0.3447),
#   ('infrastructures', 0.3407),
#   ('innovator', 0.339),
#   ('adaptive', 0.3305),
#   ('businesses', 0.3195),
#   ('business', 0.3109),
#   ('distributed', 0.3104)],
#  [('vivify', 0.5609),
#   ('cloudbased', 0.393),
#   ('provider', 0.3445),
#   ('mobile', 0.3437),
#   ('patient', 0.341),
#   ('physician', 0.3303),
#   ('health', 0.3214),
#   ('services', 0.3186),
#   ('deviceagnostic', 0.3159),
#   ('remote', 0.2844)],
#  [('architectural', 0.4606),
#   ('architecture', 0.4194),
#   ('architects', 0.3868),
#   ('sefaira', 0.3712),
#   ('building', 0.3689),
#   ('design', 0.357),
#   ('daylighting', 0.3399),
#   ('sefairas', 0.3315),
#   ('performance', 0.3216),
#   ('hvac', 0.3195)],
#  [('retail', 0.5587),
#   ('showfields', 0.4946),
#   ('brands', 0.4451),
#   ('store', 0.4152),
#   ('discover', 0.2749),
#   ('revolutionary', 0.2653),
#   ('world', 0.1916),
#   ('concept', 0.1816),
#   ('engage', 0.1382),
#   ('tomorrow', 0.1377)],
#  [('crm', 0.5709),
#   ('sales', 0.4447),
#   ('buyers', 0.4188),
#   ('manage', 0.3589),
#   ('buyer', 0.3533),
#   ('sell', 0.344),
#   ('deals', 0.3208),
#   ('stakeholders', 0.3143),
#   ('tools', 0.3063),
#   ('database', 0.2859)],
#  [('esurgcom', 0.6448),
#   ('physician', 0.3275),
#   ('pharmaceutical', 0.3246),
#   ('clinics', 0.3234),
#   ('medicine', 0.3208),
#   ('medical', 0.3046),
#   ('hospital', 0.295),
#   ('comprehensive', 0.2791),
#   ('web', 0.2437),
#   ('surgical', 0.2198)],
#  [('mertado', 0.7342),
#   ('shopping', 0.3907),
#   ('purchases', 0.3165),
#   ('products', 0.3135),
#   ('consumers', 0.3054),
#   ('social', 0.2599),
#   ('discover', 0.2466),
#   ('company', 0.2218),
#   ('buy', 0.2075),
#   ('lifestyle', 0.205)],
#  [('chat', 0.505),
#   ('privately', 0.4844),
#   ('anonymously', 0.48),
#   ('conversations', 0.4035),
#   ('conversation', 0.3927),
#   ('rumr', 0.3368),
#   ('friends', 0.2832),
#   ('realtime', 0.2826),
#   ('identity', 0.2719),
#   ('prevents', 0.1811)],
#  [('tigerconnect', 0.6682),
#   ('clients', 0.3646),
#   ('client', 0.3617),
#   ('hospital', 0.3321),
#   ('provider', 0.3314),
#   ('lifepoint', 0.3142),
#   ('hospitals', 0.3133),
#   ('workflows', 0.2998),
#   ('communicate', 0.2916),
#   ('patient', 0.2894)],
#  [('fiberzone', 0.6712),
#   ('fiberzones', 0.6493),
#   ('fiber', 0.3855),
#   ('centralized', 0.2935),
#   ('infrastructure', 0.2851),
#   ('automated', 0.2778),
#   ('automate', 0.2697),
#   ('automatic', 0.24),
#   ('networks', 0.231),
#   ('maintenance', 0.2133)],
#  [('microphone', 0.5178),
#   ('microphones', 0.5148),
#   ('acoustics', 0.4497),
#   ('acoustic', 0.4328),
#   ('piezoelectric', 0.4272),
#   ('transducer', 0.346),
#   ('vesper', 0.3439),
#   ('mems', 0.333),
#   ('handheld', 0.2671),
#   ('studio', 0.2607)],
#  [('transomic', 0.6535),
#   ('biotechnology', 0.5041),
#   ('technologies', 0.4041),
#   ('company', 0.2481),
#   ('research', 0.2443),
#   ('science', 0.237),
#   ('disease', 0.2227),
#   ('life', 0.2172),
#   ('innovative', 0.2144),
#   ('founded', 0.2123)],
#  [('zend', 0.7086),
#   ('php', 0.5396),
#   ('company', 0.2777),
#   ('httpwwwzendcom', 0.2765),
#   ('deploying', 0.2634),
#   ('provider', 0.2599),
#   ('companies', 0.2598),
#   ('headquartered', 0.2453),
#   ('technologies', 0.2425),
#   ('subsidiaries', 0.2405)],
#  [('realtybits', 0.6777),
#   ('blockchain', 0.4432),
#   ('finance', 0.3636),
#   ('invest', 0.3484),
#   ('investors', 0.347),
#   ('investment', 0.3464),
#   ('funds', 0.34),
#   ('estate', 0.312),
#   ('capital', 0.2364),
#   ('real', 0.2335)],
#  [('optical', 0.486),
#   ('metrology', 0.3973),
#   ('manufacturing', 0.3472),
#   ('technologies', 0.343),
#   ('accent', 0.3074),
#   ('industry', 0.291),
#   ('semiconductor', 0.2758),
#   ('supplier', 0.2363),
#   ('overlay', 0.195),
#   ('systems', 0.1922)],
#  [('akros', 0.4612),
#   ('silicon', 0.4331),
#   ('ics', 0.3957),
#   ('cmos', 0.3503),
#   ('korea', 0.31),
#   ('semiconductor', 0.3051),
#   ('switzerland', 0.2781),
#   ('taiwan', 0.2777),
#   ('computers', 0.2738),
#   ('companys', 0.2709)],
#  [('iamplifycom', 0.7417),
#   ('syndication', 0.4358),
#   ('publisher', 0.367),
#   ('webbased', 0.3656),
#   ('internet', 0.3133),
#   ('publish', 0.306),
#   ('content', 0.3043),
#   ('media', 0.2993),
#   ('audio', 0.2663),
#   ('providing', 0.2613)],
#  [('middleware', 0.5603),
#   ('wireless', 0.4162),
#   ('handsignal', 0.3987),
#   ('providers', 0.3545),
#   ('enterprises', 0.2065),
#   ('solutions', 0.1675),
#   ('solution', 0.1512),
#   ('develops', 0.0865)],
#  [('strataoncology', 0.6552),
#   ('strata', 0.6079),
#   ('stratas', 0.584),
#   ('oncology', 0.5515),
#   ('cancer', 0.3517),
#   ('clinical', 0.3208),
#   ('trials', 0.2859),
#   ('mutationmatched', 0.2769),
#   ('patients', 0.2504),
#   ('patient', 0.2475)],
#  [('drones', 0.523),
#   ('marine', 0.3946),
#   ('fleets', 0.3607),
#   ('ocean', 0.3017),
#   ('sensor', 0.2888),
#   ('selfpowered', 0.2725),
#   ('transmit', 0.2271),
#   ('network', 0.2148),
#   ('deployed', 0.1726),
#   ('surface', 0.1425)],
#  [('rentedcom', 0.5418),
#   ('rental', 0.4855),
#   ('realtors', 0.4375),
#   ('homeowners', 0.4236),
#   ('investors', 0.3863),
#   ('owners', 0.3372),
#   ('property', 0.3282),
#   ('customers', 0.3207),
#   ('earn', 0.3104),
#   ('managing', 0.2913)],
#  [('bountyjobs', 0.7208),
#   ('recruitment', 0.4675),
#   ('hires', 0.4086),
#   ('employers', 0.3792),
#   ('agencies', 0.3755),
#   ('rdparty', 0.3476),
#   ('tools', 0.3368),
#   ('webbased', 0.315),
#   ('collaboration', 0.3048),
#   ('search', 0.2993)],
#  [('savings', 0.5124),
#   ('financial', 0.4775),
#   ('games', 0.4362),
#   ('cash', 0.4254),
#   ('finance', 0.4139),
#   ('game', 0.3877),
#   ('prizes', 0.3734),
#   ('app', 0.3477),
#   ('personal', 0.278),
#   ('million', 0.253)],
#  [('dotphoto', 0.7907),
#   ('pictavision', 0.5662),
#   ('camera', 0.4684),
#   ('multimedia', 0.4453),
#   ('photography', 0.4339),
#   ('photos', 0.3938),
#   ('uploading', 0.3526),
#   ('webtowireless', 0.334),
#   ('photo', 0.327),
#   ('mobile', 0.3247)],
#  [('amonix', 0.548),
#   ('photovoltaic', 0.5424),
#   ('solar', 0.4014),
#   ('hcpv', 0.389),
#   ('sun', 0.2824),
# ...
#   ('palo', 0.3493),
#   ('red', 0.3275),
#   ('gaming', 0.2535),
#   ('games', 0.2414),
#   ('california', 0.2394),
#   ('founded', 0.2289),
#   ('located', 0.2284),
#   ('mobilesocial', 0.2187)],
#  [('selfcare', 0.5565),
#   ('shine', 0.395),
#   ('world', 0.312),
#   ('club', 0.3048),
#   ('digital', 0.3028),
#   ('helping', 0.2697),
#   ('treat', 0.2633),
#   ('daily', 0.252),
#   ('countries', 0.2419),
#   ('members', 0.2296)],
#  [('spruce', 0.5013),
#   ('biosciences', 0.4772),
#   ('biopharmaceutical', 0.4541),
#   ('hypothalamicpituitaryadrenal', 0.3809),
#   ('endocrine', 0.328),
#   ('therapies', 0.3194),
#   ('clinicalstage', 0.2648),
#   ('treatments', 0.2542),
#   ('pathway', 0.2532),
#   ('stress', 0.2499)],
#  [('media', 0.4113),
#   ('marketing', 0.3801),
#   ('advertising', 0.3342),
#   ('insurance', 0.3234),
#   ('lead', 0.2985),
#   ('campaign', 0.2863),
#   ('lucky', 0.2766),
#   ('business', 0.2565),
#   ('agency', 0.2527),
#   ('health', 0.2482)],
#  [('blogtalkradio', 0.8434),
#   ('podcast', 0.4777),
#   ('talkshow', 0.3823),
#   ('radio', 0.3773),
#   ('web', 0.2707),
#   ('site', 0.2607),
#   ('phone', 0.2552),
#   ('participate', 0.1824),
#   ('users', 0.1814),
#   ('number', 0.179)],
#  [('mover', 0.5141),
#   ('updater', 0.502),
#   ('realtors', 0.4023),
#   ('relocation', 0.3361),
#   ('headquartered', 0.3351),
#   ('brokers', 0.3014),
#   ('moving', 0.2954),
#   ('innovative', 0.2951),
#   ('managers', 0.282),
#   ('housing', 0.28)],
#  [('awardstar', 0.5228),
#   ('kinexxia', 0.5119),
#   ('competitions', 0.4259),
#   ('scholarship', 0.4043),
#   ('award', 0.3855),
#   ('platform', 0.3116),
#   ('programs', 0.2668),
#   ('sharing', 0.2183),
#   ('companies', 0.2095),
#   ('manage', 0.165)],
#  [('niiki', 0.5481),
#   ('pharma', 0.4804),
#   ('oncology', 0.4271),
#   ('cancer', 0.383),
#   ('drug', 0.3223),
#   ('treatments', 0.2131),
#   ('programs', 0.193),
#   ('development', 0.1914),
#   ('company', 0.1728),
#   ('cellular', 0.1633)],
#  [('silicon', 0.554),
#   ('semiconductor', 0.3435),
#   ('technologies', 0.3407),
#   ('supplier', 0.3065),
#   ('corp', 0.2987),
#   ('technology', 0.2955),
#   ('company', 0.2896),
#   ('china', 0.2804),
#   ('legend', 0.2782),
#   ('beijing', 0.2688)],
#  [('ziprecruiter', 0.7679),
#   ('employment', 0.2401),
#   ('marketplace', 0.2333),
#   ('job', 0.2279),
#   ('search', 0.2251),
#   ('businesses', 0.2092),
#   ('matching', 0.2091),
#   ('mobile', 0.1998),
#   ('app', 0.1985),
#   ('seekers', 0.1939)],
#  [('ossianix', 0.5631),
#   ('antibody', 0.4371),
#   ('antibodies', 0.4174),
#   ('vnar', 0.3617),
#   ('biotherapeutics', 0.3013),
#   ('shark', 0.2917),
#   ('monoclonal', 0.2454),
#   ('biophysical', 0.2346),
#   ('platform', 0.207),
#   ('biological', 0.1894)],
#  [('andera', 0.6677),
#   ('acquisition', 0.3564),
#   ('banks', 0.308),
#   ('account', 0.2776),
#   ('marketing', 0.2761),
#   ('customer', 0.2741),
#   ('retail', 0.2734),
#   ('crossselling', 0.2685),
#   ('credit', 0.2384),
#   ('online', 0.2319)],
#  [('podshow', 0.6869),
#   ('podcasts', 0.567),
#   ('audio', 0.4281),
#   ('media', 0.3692),
#   ('music', 0.3299),
#   ('singleclick', 0.2898),
#   ('network', 0.2465),
#   ('video', 0.2172),
#   ('access', 0.1787),
#   ('providing', 0.1499)],
#  [('biolabs', 0.5129),
#   ('cattle', 0.4095),
#   ('genomic', 0.4012),
#   ('beef', 0.3497),
#   ('dairy', 0.2736),
#   ('tests', 0.2546),
#   ('software', 0.2324),
#   ('free', 0.2092),
#   ('tl', 0.2091),
#   ('results', 0.1726)],
#  [('docent', 0.5089),
#   ('customercentric', 0.4765),
#   ('service', 0.4237),
#   ('hospitality', 0.4107),
#   ('mission', 0.3749),
#   ('marketing', 0.3745),
#   ('healths', 0.3628),
#   ('customer', 0.3448),
#   ('health', 0.3381),
#   ('consumer', 0.3269)],
#  [('fashionplaytes', 0.7288),
#   ('fashionplaytescom', 0.6648),
#   ('fashion', 0.5654),
#   ('dresses', 0.4819),
#   ('designers', 0.4633),
#   ('girls', 0.4244),
#   ('designityourself', 0.3826),
#   ('design', 0.375),
#   ('hoodies', 0.3696),
#   ('style', 0.3394)],
#  [('apps', 0.5613),
#   ('app', 0.529),
#   ('prisma', 0.4888),
#   ('ios', 0.4397),
#   ('api', 0.4207),
#   ('art', 0.4119),
#   ('photos', 0.3965),
#   ('android', 0.3939),
#   ('paintings', 0.3933),
#   ('appstore', 0.3686)],
#  [('cloudbased', 0.478),
#   ('bioinformatics', 0.4533),
#   ('genomics', 0.4326),
#   ('clouddx', 0.4012),
#   ('cloud', 0.3854),
#   ('genomescale', 0.383),
#   ('researchdeveloped', 0.3675),
#   ('clinical', 0.3292),
#   ('patientcentered', 0.3235),
#   ('sequencing', 0.3153)],
#  [('anvil', 0.4686),
#   ('microarrays', 0.3898),
#   ('genomics', 0.3741),
#   ('data', 0.3428),
#   ('cheminformatics', 0.3376),
#   ('informatics', 0.3373),
#   ('proteomics', 0.3151),
#   ('discovery', 0.2903),
#   ('visualization', 0.2651),
#   ('pharmaceutical', 0.2475)],
#  [('omni', 0.541),
#   ('water', 0.3563),
#   ('octozone', 0.2997),
#   ('contaminated', 0.2462),
#   ('highvolume', 0.2052),
#   ('company', 0.2018),
#   ('solutions', 0.2005),
#   ('automation', 0.1883),
#   ('technology', 0.1882),
#   ('maintenance', 0.1807)],
#  [('supercar', 0.3886),
#   ('manufacturing', 0.3857),
#   ('prototype', 0.3769),
#   ('printing', 0.3504),
#   ('innovation', 0.3266),
#   ('tools', 0.3072),
#   ('printed', 0.3019),
#   ('patented', 0.2982),
#   ('vehicle', 0.2885),
#   ('connectors', 0.2876)],
#  [('veracyte', 0.5656),
#   ('calderome', 0.4574),
#   ('cancer', 0.3213),
#   ('thyroid', 0.3042),
#   ('company', 0.2891),
#   ('incorporated', 0.285),
#   ('diagnostics', 0.2541),
#   ('lung', 0.2013),
#   ('based', 0.1324),
#   ('francisco', 0.1217)],
#  [('cardiac', 0.405),
#   ('cheetah', 0.3813),
#   ('nicom', 0.3627),
#   ('fda', 0.3505),
#   ('clinical', 0.2875),
#   ('medical', 0.2702),
#   ('thermodilution', 0.248),
#   ('clinicians', 0.2441),
#   ('regulatory', 0.2156),
#   ('monitor', 0.2111)],
#  [('storr', 0.6989),
#   ('retailers', 0.4265),
#   ('retail', 0.405),
#   ('marketplace', 0.3577),
#   ('macy', 0.3517),
#   ('brands', 0.3478),
#   ('brand', 0.3458),
#   ('market', 0.3441),
#   ('ventures', 0.3288),
#   ('glossier', 0.3155)],
#  [('oculis', 0.6002),
#   ('labs', 0.401),
#   ('screen', 0.373),
#   ('calibrate', 0.313),
#   ('tracking', 0.2837),
#   ('computer', 0.2821),
#   ('eye', 0.2742),
#   ('uses', 0.235),
#   ('security', 0.2226),
#   ('technology', 0.2143)],
#  [('margarita', 0.4352),
#   ('cocktails', 0.4083),
#   ('liquor', 0.3949),
#   ('cocktail', 0.3905),
#   ('martini', 0.3873),
#   ('lemon', 0.3837),
#   ('paula', 0.3799),
#   ('flavor', 0.3253),
#   ('orange', 0.3155),
#   ('fruit', 0.2982)],
#  [('satellite', 0.5348),
#   ('endtoend', 0.5191),
#   ('missions', 0.4539),
#   ('software', 0.4034),
#   ('platform', 0.3543)],
#  [('outspark', 0.5669),
#   ('mmos', 0.5266),
#   ('publisher', 0.3774),
#   ('platform', 0.3605),
#   ('publish', 0.3264),
#   ('publishing', 0.3135),
#   ('games', 0.3084),
#   ('companys', 0.3012),
#   ('founder', 0.2956),
#   ('ceo', 0.2895)],
#  [('macstadium', 0.5966),
#   ('macs', 0.5498),
#   ('mac', 0.5382),
#   ('iosmac', 0.5377),
#   ('macos', 0.4962),
#   ('apple', 0.4595),
#   ('infrastructure', 0.334),
#   ('devops', 0.334),
#   ('enterpriseclass', 0.3258),
#   ('ios', 0.3093)],
#  [('autofi', 0.6406),
#   ('automated', 0.4404),
#   ('financing', 0.3609),
#   ('finance', 0.3049),
#   ('vehicle', 0.2978),
#   ('purchase', 0.2139),
#   ('application', 0.1768),
#   ('sale', 0.1683),
#   ('online', 0.1511),
#   ('consumers', 0.1207)],
#  [('matchmaking', 0.4901),
#   ('matchmakers', 0.4384),
#   ('dating', 0.351),
#   ('plans', 0.3163),
#   ('business', 0.3127),
#   ('freemium', 0.2993),
#   ('match', 0.2923),
#   ('online', 0.2731),
#   ('profile', 0.2533),
#   ('inefficiencies', 0.2507)],
#  [('carsabi', 0.5113),
#   ('dealership', 0.3794),
#   ('listings', 0.3592),
#   ('craigslist', 0.3514),
#   ('websites', 0.3068),
#   ('classifieds', 0.3026),
#   ('deals', 0.2939),
#   ('car', 0.2784),
#   ('web', 0.2731),
#   ('sale', 0.2653)],
#  [('foodservice', 0.5779),
#   ('rtis', 0.457),
#   ('fryer', 0.4306),
#   ('rti', 0.4091),
#   ('restaurant', 0.3704),
#   ('oil', 0.3441),
#   ('frying', 0.3346),
#   ('services', 0.3067),
#   ('mcdonalds', 0.3016),
#   ('analytics', 0.2655)],
#  [('friends', 0.466),
#   ('trusted', 0.3826),
#   ('loyalty', 0.3646),
#   ('brands', 0.3588),
#   ('marketing', 0.3288),
#   ('crosslink', 0.3241),
#   ('provider', 0.321),
#   ('backed', 0.292),
#   ('investors', 0.2396),
#   ('retailer', 0.2096)],
#  [('vigilent', 0.6991),
#   ('critical', 0.2942),
#   ('cooling', 0.2933),
#   ('mission', 0.2806),
#   ('facilities', 0.2696),
#   ('san', 0.2602),
#   ('sustainable', 0.2532),
#   ('software', 0.2326),
#   ('technology', 0.2218),
#   ('energy', 0.2161)],
#  [('yardbarkercom', 0.5185),
#   ('yardbarker', 0.4727),
#   ('blogs', 0.4289),
#   ('blog', 0.4012),
#   ('farkcom', 0.381),
#   ('sports', 0.3668),
#   ('content', 0.3339),
#   ('news', 0.327),
#   ('hub', 0.324),
#   ('articles', 0.3193)],
#  [('byallaccounts', 0.5436),
#   ('accounts', 0.5032),
#   ('accounting', 0.4853),
#   ('account', 0.4276),
#   ('banking', 0.3803),
#   ('consolidated', 0.3487),
#   ('financial', 0.3466),
#   ('portfolio', 0.3343),
#   ('annuity', 0.315),
#   ('brokerage', 0.3137)],
#  [('parse', 0.4815),
#   ('cloudbased', 0.4287),
#   ('apps', 0.416),
#   ('cloud', 0.3792),
#   ('datastore', 0.3314),
#   ('app', 0.3289),
#   ('analytics', 0.3172),
#   ('developer', 0.2845),
#   ('notifications', 0.2681),
#   ('facebook', 0.2615)],
#  [('marketresearchcoms', 0.6148),
#   ('market', 0.4846),
#   ('research', 0.4446),
#   ('pinterest', 0.3546),
#   ('tools', 0.2452),
#   ('insights', 0.2306),
#   ('advice', 0.2108),
#   ('process', 0.1976),
#   ('helpful', 0.1838),
#   ('howtos', 0.1763)],
#  [('bottlenose', 0.7328),
#   ('bottlenoseapp', 0.6347),
#   ('analytics', 0.3779),
#   ('organization', 0.3213),
#   ('company', 0.3141),
#   ('data', 0.3124),
#   ('platform', 0.3121),
#   ('business', 0.3013),
#   ('managing', 0.2932),
#   ('clients', 0.2863)],
#  [('chartboost', 0.7119),
#   ('wwwchartboostcom', 0.502),
#   ('advertisers', 0.3829),
#   ('sdk', 0.3686),
#   ('android', 0.3109),
#   ('platform', 0.3),
#   ('mobile', 0.2981),
#   ('monetization', 0.2936),
#   ('largest', 0.2905),
#   ('ad', 0.29)],
#  [('milpitas', 0.3579),
#   ('stealth', 0.343),
#   ('califbased', 0.3304),
#   ('storage', 0.325),
#   ('mode', 0.2183),
#   ('network', 0.2176),
#   ('data', 0.2011),
#   ('management', 0.192),
#   ('came', 0.001)],
#  [('neurotech', 0.5452),
#   ('cervel', 0.5355),
#   ('neuromodulation', 0.4584),
#   ('transcranial', 0.4059),
#   ('neurosciences', 0.3651),
#   ('stimulation', 0.3101),
#   ('neostim', 0.2973),
#   ('brain', 0.2846),
#   ('magnetic', 0.2845),
#   ('rtms', 0.2642)],
#  [('omneon', 0.4394),
#   ('satellite', 0.3855),
#   ('providers', 0.3726),
#   ('multichannel', 0.3583),
#   ('television', 0.3464),
#   ('mediagrid', 0.3423),
#   ('broadcasters', 0.3397),
#   ('media', 0.3311),
#   ('servers', 0.3174),
#   ('mobile', 0.3105)],
#  [('appature', 0.5327),
#   ('nexxus', 0.4216),
#   ('ims', 0.3628),
#   ('cloudbased', 0.3609),
#   ('marketing', 0.326),
#   ('healthcare', 0.3063),
#   ('companies', 0.2419),
#   ('acquired', 0.2403),
#   ('health', 0.2402),
#   ('platform', 0.2393)],
#  [('clearview', 0.5682),
#   ('social', 0.462),
#   ('facebook', 0.4262),
#   ('twitter', 0.3728),
#   ('advocacy', 0.3504),
#   ('linkedin', 0.3411),
#   ('shared', 0.2971),
#   ('share', 0.273),
#   ('employees', 0.2429),
#   ('business', 0.2252)],
#  [('exalt', 0.5656),
#   ('communications', 0.4086),
#   ('wireless', 0.3674),
#   ('wifi', 0.3125),
#   ('radio', 0.2921),
#   ('providers', 0.2825),
#   ('network', 0.2778),
#   ('carriers', 0.2644),
#   ('isps', 0.2551),
#   ('mobile', 0.2427)],
#  [('resonext', 0.6347),
#   ('wlan', 0.441),
#   ('metaloxidesemiconductor', 0.4139),
#   ('wireless', 0.3841),
#   ('cmos', 0.3508),
#   ('network', 0.2612),
#   ('multiband', 0.2513),
#   ('provider', 0.2258),
#   ('silicon', 0.2088),
#   ('integrated', 0.1933)],
#  [('dicerna', 0.6255),
#   ('dicer', 0.5087),
#   ('rnai', 0.4892),
#   ('rna', 0.4806),
#   ('pharmaceuticals', 0.4045),
#   ('rnaitargeted', 0.395),
#   ('biopharmaceutical', 0.357),
#   ('gene', 0.3434),
#   ('oncology', 0.273),
#   ('company', 0.2695)],
#  [('hudl', 0.698),
#   ('coaching', 0.3679),
#   ('sports', 0.3441),
#   ('coaches', 0.3223),
#   ('athletes', 0.2843),
#   ('nfl', 0.2785),
#   ('nhl', 0.2633),
#   ('software', 0.2613),
#   ('nba', 0.2576),
#   ('teams', 0.2542)],
#  [('galileo', 0.6494),
#   ('health', 0.4516),
#   ('organisation', 0.3064),
#   ('care', 0.2142)],
#  [('mobile', 0.4868),
#   ('commerce', 0.4785),
#   ('pay', 0.4318),
#   ('phone', 0.3876)],
#  [('clickshift', 0.7367),
#   ('webtrends', 0.3532),
#   ('web', 0.3184),
#   ('software', 0.3029),
#   ('advertising', 0.2859),
#   ('tunes', 0.2487),
#   ('company', 0.2363),
#   ('campaigns', 0.2342),
#   ('corporation', 0.2304),
#   ('founded', 0.1964)],
#  [('stedi', 0.5954),
#   ('edi', 0.4594),
#   ('automate', 0.2677),
#   ('transaction', 0.2668),
#   ('fees', 0.2232),
#   ('fastest', 0.2046),
#   ('fee', 0.2),
#   ('implement', 0.183),
#   ('pertransaction', 0.1802),
#   ('manage', 0.174)],
#  [('cardionet', 0.6187),
#   ('cardionets', 0.5625),
#   ('cardiac', 0.4946),
#   ('ecg', 0.4781),
#   ('arrhythmias', 0.4023),
#   ('biotel', 0.3998),
#   ('telemetry', 0.3446),
#   ('heart', 0.3378),
#   ('monitoring', 0.3131),
#   ('marketed', 0.281)],
#  [('cardonet', 0.5243),
#   ('catalogs', 0.4872),
#   ('marketplace', 0.4343),
#   ('emarketplaces', 0.4215),
#   ('buyers', 0.3612),
#   ('transactions', 0.3043),
#   ('transactive', 0.296),
#   ('experience', 0.2588),
#   ('enhance', 0.2099),
#   ('maintain', 0.1896)],
#  [('springleaf', 0.5137),
#   ('springleafs', 0.4923),
#   ('therapeutics', 0.4259),
#   ('pharmaceuticals', 0.4121),
#   ('therapeutic', 0.3702),
#   ('breakthrough', 0.3455),
#   ('entra', 0.312),
#   ('patients', 0.2651),
#   ('venture', 0.2427),
#   ('innovative', 0.2229)],
#  [('imagekind', 0.5617),
#   ('galleries', 0.5163),
#   ('art', 0.4484),
#   ('canvas', 0.3976),
#   ('partnered', 0.3674),
#   ('flickrhttpwwwcrunchbasecomorganizationflickr', 0.3559),
#   ('artist', 0.3492),
#   ('brands', 0.3466),
#   ('commissions', 0.3188),
#   ('walgreens', 0.2913)],
#  [('bioconnect', 0.4983),
#   ('implants', 0.4275),
#   ('vascular', 0.3965),
#   ('connectors', 0.39),
#   ('vessels', 0.3441),
#   ('surgical', 0.2886),
#   ('connections', 0.2716),
#   ('anastomotic', 0.2352),
#   ('sutureless', 0.2323),
#   ('connecting', 0.2066)],
#  [('teros', 0.4797),
#   ('firewalls', 0.4436),
#   ('security', 0.3615),
#   ('web', 0.3171),
#   ('fireline', 0.3153),
#   ('applications', 0.2992),
#   ('teross', 0.2963),
#   ('intrusion', 0.293),
#   ('secure', 0.2913),
#   ('services', 0.2906)],
#  [('formatta', 0.6934),
#   ('forms', 0.4376),
#   ('electronically', 0.3965),
#   ('software', 0.3685),
#   ('data', 0.3164),
#   ('signatures', 0.2464),
#   ('organizations', 0.2411),
#   ('distributed', 0.2409),
#   ('systems', 0.2331),
#   ('businesses', 0.2252)],
#  [('mortgage', 0.6315),
#   ('estate', 0.4036),
#   ('provider', 0.3982),
#   ('online', 0.3142),
#   ('services', 0.3098),
#   ('home', 0.3083),
#   ('real', 0.1345)],
#  [('vts', 0.6035),
#   ('vt', 0.602),
#   ('silicon', 0.4108),
#   ('transceivers', 0.3481),
#   ('amplifiers', 0.3472),
#   ('technologies', 0.3427),
#   ('manufacturers', 0.3208),
#   ('manufacture', 0.3159),
#   ('silicongermanium', 0.3057),
#   ('linearization', 0.2786)],
#  [('node', 0.526),
#   ('ai', 0.4145),
#   ('aiasaservice', 0.3771),
#   ('enterprises', 0.3731),
#   ('ventures', 0.3615),
#   ('openx', 0.3408),
#   ('customers', 0.3052),
#   ('investors', 0.3025),
#   ('googles', 0.3008),
#   ('applications', 0.2959)],
#  [('estate', 0.3898),
#   ('loan', 0.361),
#   ('financial', 0.3397),
#   ('appraisal', 0.3255),
#   ('services', 0.2989),
#   ('valuation', 0.2689),
#   ('group', 0.2594),
#   ('insurance', 0.2356),
#   ('searches', 0.2192),
#   ('provides', 0.2189)],
#  [('careacademy', 0.6407),
#   ('caregivers', 0.615),
#   ('caregiver', 0.5855),
#   ('nanny', 0.4176),
#   ('care', 0.405),
#   ('agencies', 0.3329),
#   ('certified', 0.3317),
#   ('seniors', 0.3069),
#   ('professional', 0.3066),
#   ('homes', 0.3028)],
#  [('avchem', 0.7365),
#   ('management', 0.3496),
#   ('chemical', 0.3496),
#   ('services', 0.247),
#   ('provider', 0.2386)],
#  [('planetfeedback', 0.7935),
#   ('service', 0.3051),
#   ('web', 0.2977),
#   ('consumers', 0.2039),
#   ('companies', 0.1752),
#   ('communicate', 0.1668),
#   ('new', 0.1417),
#   ('designed', 0.1375),
#   ('help', 0.0988),
#   ('effectively', 0.0915)],
#  [('ios', 0.4436),
#   ('android', 0.4087),
#   ('beta', 0.3855),
#   ('recommendme', 0.3267),
#   ('private', 0.309),
#   ('email', 0.3077),
#   ('available', 0.2251),
#   ('code', 0.1819),
#   ('use', 0.1805),
#   ('let', 0.1781)],
#  [('xcelerate', 0.4796),
#   ('marketplaces', 0.4555),
#   ('clients', 0.3073),
#   ('founded', 0.239),
#   ('bb', 0.1935),
#   ('florida', 0.191),
#   ('based', 0.1573),
#   ('develops', 0.1364),
#   ('range', 0.1277)],
#  ...]

# %%
company['keywords'] = keywords

# %%
company
# Out:
#                 company_name  \
# 0                 Codementor
# 1                    AgShift
# 2                     Shipsi
# 3                   OpenNews
# 4           Biobot Analytics
# ...                      ...
# 19960  Powermat Technologies
# 19961               Properly
# 19962                Bid Ops
# 19963                 Tavolo
# 19964               StackMob
#
#                                      company_description  \
# 0      codementor provides live  help for software de...
# 1      agshift solution blends deep learning with com...
# 2      shipsi empowers any retailer with the ability ...
# 3      were helping a global network of developers jo...
# 4      biobot analytics analyzes sewage to estimate o...
# ...                                                  ...
# 19960  powermat technologies is a developer of wirele...
# 19961  properly is a visual checklist tool that lets ...
# 19962  bid ops accelerates business partnerships betw...
# 19963  tavolo offers an online store that enables its...
# 19964  stackmob’s mobile platform helps developers cr...
#
#                                                 keywords
# 0      [(codementor, 0.5403), (developers, 0.4031), (...
# 1      [(agshift, 0.3913), (software, 0.3842), (learn...
# 2      [(shipsi, 0.6162), (logistics, 0.3932), (shipp...
# 3      [(developers, 0.5045), (journalism, 0.4972), (...
# 4      [(biobot, 0.4356), (wastewater, 0.4233), (opio...
# ...                                                  ...
# 19960  [(powermat, 0.4932), (powermats, 0.4902), (cha...
# 19961  [(cleaning, 0.3997), (cleaners, 0.3594), (prop...
# 19962  [(partnerships, 0.5327), (bid, 0.481), (suppli...
# 19963  [(tavolo, 0.585), (store, 0.3677), (products, ...
# 19964  [(stackmob, 0.5913), (mobile, 0.4721), (apps, ...
#
# [19965 rows x 3 columns]

# %%
def keyword_preprocess(list1):
    return [item for t in list1 for item in t if type(item)==str]

# %%
company['keywords'] = company['keywords'].apply(keyword_preprocess)

# %%
company
# Out:
#                 company_name  \
# 0                 Codementor
# 1                    AgShift
# 2                     Shipsi
# 3                   OpenNews
# 4           Biobot Analytics
# ...                      ...
# 19960  Powermat Technologies
# 19961               Properly
# 19962                Bid Ops
# 19963                 Tavolo
# 19964               StackMob
#
#                                      company_description  \
# 0      codementor provides live  help for software de...
# 1      agshift solution blends deep learning with com...
# 2      shipsi empowers any retailer with the ability ...
# 3      were helping a global network of developers jo...
# 4      biobot analytics analyzes sewage to estimate o...
# ...                                                  ...
# 19960  powermat technologies is a developer of wirele...
# 19961  properly is a visual checklist tool that lets ...
# 19962  bid ops accelerates business partnerships betw...
# 19963  tavolo offers an online store that enables its...
# 19964  stackmob’s mobile platform helps developers cr...
#
#                                                 keywords
# 0      [codementor, developers, mentorship, software,...
# 1      [agshift, software, learning, vision, images, ...
# 2      [shipsi, logistics, shipping, retailer, delive...
# 3      [developers, journalism, journalists, hackers,...
# 4      [biobot, wastewater, opioids, sewage, analytic...
# ...                                                  ...
# 19960  [powermat, powermats, charging, airport, durac...
# 19961  [cleaning, cleaners, properly, properlys, chec...
# 19962  [partnerships, bid, suppliers, buyers, busines...
# 19963  [tavolo, store, products, san, buy, cooking, c...
# 19964  [stackmob, mobile, apps, frontend, platform, b...
#
# [19965 rows x 3 columns]

# %%
industry = pd.read_excel("Industry Segments - Top 10 Keywords.xlsx")
industry
# Out:
#                              Industry segment  \
# 0                       Aerospace and defense
# 1                    Agriculture and forestry
# 2                          Biopharmaceuticals
# 3                   Business support services
# 4               Communications and networking
# 5          Construction and civil engineering
# 6               Consumer information services
# 7           Electronics and computer hardware
# 8         Financial institutions and services
# 9                           Food and beverage
# 10                        Healthcare services
# 11                 Household and office goods
# 12             Machinery and industrial goods
# 13                    Materials and chemicals
# 14                          Media and content
# 15              Medical devices and equipment
# 16  Medical software and information services
# 17                       Non-renewable energy
# 18                             Personal goods
# 19                           Renewable energy
# 20                                  Retailers
# 21                             Semiconductors
# 22                                   Software
# 23                         Travel and leisure
# 24                                  Utilities
# 25                         Vehicles and parts
# 26               Wholesale trade and shipping
#
#                                                  Tags
# 0   security, systems, video, surveillance, servic...
# 1   Service, cleantech, water, agriculture, traits...
# 2   Developer, treatment, drug, diseases, technolo...
# 3   Service, platform, online, management, data, m...
# 4   Service, wireless, network, data, internet, ap...
# 5   Service, cleantech, water, energy, waste, trea...
# 6   Online, users, web, service, platform, social,...
# 7   Technology, storage, energy, systems, applicat...
# 8   Service, financial, payment, online, platform,...
# 9   Food, organic, tea, beverages, ingredients, na...
# 10  Service, care, healthcare, health, management,...
# 11  Water, energy, cleantech, efficiency, service,...
# 12  Energy, technology, efficiency, cleantech, sys...
# 13  Materials, technology, cleantech, applications...
# 14  Content, online, service, platform, web, media...
# 15  Developer, technology, devices, medical, treat...
# 16  Healthcare, management, service, health, softw...
# 17  Gas, oil, natural, technology, service, cleant...
# 18  Skin, care, technology, accessories, online, p...
# 19  Solar, cleantech, energy, generation, technolo...
# 20  Online, service, accessories, web, stores, cus...
# 21  Technology, power, developer, semiconductor, a...
# 22  Software, service, management, data, platform,...
# 23  Travel, service, online, vacation, search, res...
# 24  Energy, water, power, service, efficiency, cle...
# 25  Electric, vehicles, transportation, cleantech,...
# 26  Transportation, management, shipping, service,...

# %%
#pip install openpyxl
